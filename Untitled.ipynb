# %% [markdown]
# # Compare two GEOS-Chem diagnostic datasets
# Includes GEOS-Chem Classic and GCHP, binary and netcdf formats. Datasets on different grids and at different grid resolutions can be compared directly following the example in this notebook. Plots may be displayed inline in this notebook or sent to PDF.

# %% [markdown]
# ## Tips for using Jupyter Notebook
#
# 1. You can use unix commands such as ls and pwd
# 2. Hover over a function and press Shift-Tab to see function arguments
# 3. Access documentation with help(fnct) or fnct?, where fnct is function name
# 4. See function source code with fnct??
# 5. Use tab-complete to see what is possible, e.g. gcpy.cTAB
# 6. Explore modules with dir(module), e.g. dir(gcpy) or dir(gcpy.core)

# %% [markdown]
# ## Import dependencies

# %%
import os
import numpy as np
import xarray as xr
import xbpch
import gcpy

# Enable auto-reloading modules
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import warnings; warnings.filterwarnings("ignore")

# %% [markdown]
# ## Choose comparison type

# %%
# Choose comparison type: 
#   'bpch' = bpch vs bpch
#   'nc' = nc vs nc
#.  'bpch_vs_nc' = bpch vs nc
# NOTE: The example in the existing settings of this notebook is for bpch vs nc

#comparison = 'bpch'
comparison = 'nc'
#comparison = 'bpch_vs_nc'

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Binary data (if using)

# %%
# Set bpch ref data is doing bpch vs nc or bpch vs bpch
if 'bpch' in comparison:
    refdir = '/path/to/ref/binary/file/'
    refbpfile = os.path.join(refdir,'trac_avg.geosfp_4x5_standard.201607010000')
    reftracerinfo = os.path.join(refdir,'tracerinfo.dat') 
    refdiaginfo = os.path.join(refdir,'diaginfo.dat')
    refdata = xbpch.open_bpchdataset(refbpfile, tracerinfo_file=reftracerinfo, diaginfo_file=refdiaginfo)
    
# Set bpch dev data if doing bpch vs bpch
if comparison == 'bpch':
    devdir = '/path/to/dev/binary/file'
    devbpfile = os.path.join(devdir,'trac_avg.geosfp_4x5_standard.201607010000')
    devtracerinfo = os.path.join(devdir,'tracerinfo.dat') 
    devdiaginfo = os.path.join(devdir,'diaginfo.dat')
    devdata = xbpch.open_bpchdataset(devbpfile, tracerinfo_file=reftracerinfo, diaginfo_file=refdiaginfo)

# %% [markdown]
# ### Netcdf data (if using)

# %%
# Set netcdf ref data if doing nc vs nc
if comparison == 'nc':
    refdata = xr.open_dataset('../../GCrundirs/test_NEI_jan_orig2011NEI/geosfp_4x5_standard/output_2013/GEOSChem.SpeciesConc.20160101_0000z.nc4')
    
# Set netcdf dev data if doing bpch vs nc
if 'nc' in comparison:
    devdata = xr.open_dataset('../../GCrundirs/benchmark_jan_EPA/geosfp_4x5_benchmark/OutputDir/GEOSChem.SpeciesConc.20160101_0000z.nc4')

# %% [markdown]
# ### Inspect datasets

# %%
refdata
# Out:
# <xarray.Dataset>
# Dimensions:               (ilev: 73, lat: 46, lev: 72, lon: 72, time: 1)
# Coordinates:
#   * time                  (time) datetime64[ns] 2016-01-16T12:00:00
#   * lev                   (lev) float64 0.9925 0.9775 ... 2.635e-05 1.5e-05
#   * ilev                  (ilev) float64 1.0 0.985 0.97 ... 3.27e-05 2e-05 1e-05
#   * lat                   (lat) float64 -89.0 -86.0 -82.0 ... 82.0 86.0 89.0
#   * lon                   (lon) float64 -180.0 -175.0 -170.0 ... 170.0 175.0
# Data variables:
#     hyam                  (lev) float64 ...
#     hybm                  (lev) float64 ...
#     hyai                  (ilev) float64 ...
#     hybi                  (ilev) float64 ...
#     P0                    float64 ...
#     AREA                  (lat, lon) float32 ...
#     SpeciesConc_XYLE      (time, lev, lat, lon) float32 ...
#     SpeciesConc_TOLU      (time, lev, lat, lon) float32 ...
#     SpeciesConc_SOAS      (time, lev, lat, lon) float32 ...
#     SpeciesConc_SOAP      (time, lev, lat, lon) float32 ...
#     SpeciesConc_SOAIE     (time, lev, lat, lon) float32 ...
#     SpeciesConc_SOAGX     (time, lev, lat, lon) float32 ...
#     SpeciesConc_SO4s      (time, lev, lat, lon) float32 ...
#     SpeciesConc_SO4       (time, lev, lat, lon) float32 ...
#     SpeciesConc_SO2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_SALC      (time, lev, lat, lon) float32 ...
#     SpeciesConc_SALA      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RP        (time, lev, lat, lon) float32 ...
#     SpeciesConc_RIPD      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RIPC      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RIPB      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RIPA      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RCHO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RB3P      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RA3P      (time, lev, lat, lon) float32 ...
#     SpeciesConc_R4P       (time, lev, lat, lon) float32 ...
#     SpeciesConc_R4N2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PYAC      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PRPN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PRPE      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PROPNN    (time, lev, lat, lon) float32 ...
#     SpeciesConc_PPN       (time, lev, lat, lon) float32 ...
#     SpeciesConc_PP        (time, lev, lat, lon) float32 ...
#     SpeciesConc_PIP       (time, lev, lat, lon) float32 ...
#     SpeciesConc_pFe       (time, lev, lat, lon) float32 ...
#     SpeciesConc_PAN       (time, lev, lat, lon) float32 ...
#     SpeciesConc_OIO       (time, lev, lat, lon) float32 ...
#     SpeciesConc_OCS       (time, lev, lat, lon) float32 ...
#     SpeciesConc_OCPO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_OCPI      (time, lev, lat, lon) float32 ...
#     SpeciesConc_OClO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_O3        (time, lev, lat, lon) float32 ...
#     SpeciesConc_NPRNO3    (time, lev, lat, lon) float32 ...
#     SpeciesConc_NO3       (time, lev, lat, lon) float32 ...
#     SpeciesConc_NO2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_NO        (time, lev, lat, lon) float32 ...
#     SpeciesConc_NITs      (time, lev, lat, lon) float32 ...
#     SpeciesConc_NIT       (time, lev, lat, lon) float32 ...
#     SpeciesConc_NH4       (time, lev, lat, lon) float32 ...
#     SpeciesConc_NH3       (time, lev, lat, lon) float32 ...
#     SpeciesConc_N2O5      (time, lev, lat, lon) float32 ...
#     SpeciesConc_N2O       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKPC     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKHP     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKHCB    (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKHC     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKDH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVK       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MTPO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MTPA      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MSA       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MPN       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MPAN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MP        (time, lev, lat, lon) float32 ...
#     SpeciesConc_MONITU    (time, lev, lat, lon) float32 ...
#     SpeciesConc_MONITS    (time, lev, lat, lon) float32 ...
#     SpeciesConc_MONITA    (time, lev, lat, lon) float32 ...
#     SpeciesConc_MOH       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MGLY      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MENO3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MEK       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCRHP     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCRHNB    (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCRHN     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCRENOL   (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCRDH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MAP       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MACR1OOH  (time, lev, lat, lon) float32 ...
#     SpeciesConc_MACR      (time, lev, lat, lon) float32 ...
#     SpeciesConc_LVOCOA    (time, lev, lat, lon) float32 ...
#     SpeciesConc_LVOC      (time, lev, lat, lon) float32 ...
#     SpeciesConc_LIMO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ITHN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ITCN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ISOP      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ISALC     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ISALA     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IPRNO3    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IONO2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IONO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IONITA    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IO        (time, lev, lat, lon) float32 ...
#     SpeciesConc_INPD      (time, lev, lat, lon) float32 ...
#     SpeciesConc_INPB      (time, lev, lat, lon) float32 ...
#     SpeciesConc_INO       (time, lev, lat, lon) float32 ...
#     SpeciesConc_INDIOL    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHN4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHN3      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHN2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHN1      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IEPOXD    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IEPOXB    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IEPOXA    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDN       (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDHPE     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDHDP     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDCHP     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDC       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ICPDH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ICN       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ICl       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ICHE      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IBr       (time, lev, lat, lon) float32 ...
#     SpeciesConc_I2O4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_I2O3      (time, lev, lat, lon) float32 ...
#     SpeciesConc_I2O2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_I2        (time, lev, lat, lon) float32 ...
#     SpeciesConc_I         (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPETHNL   (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPALD4    (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPALD3    (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPALD2    (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPALD1    (time, lev, lat, lon) float32 ...
#     SpeciesConc_HONIT     (time, lev, lat, lon) float32 ...
#     SpeciesConc_HOI       (time, lev, lat, lon) float32 ...
#     SpeciesConc_HOCl      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HOBr      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HNO4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HNO3      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HNO2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HMML      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HMHP      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HI        (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCOOH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCl       (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCFC22    (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCFC142b  (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCFC141b  (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCFC123   (time, lev, lat, lon) float32 ...
#     SpeciesConc_HC5A      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HBr       (time, lev, lat, lon) float32 ...
#     SpeciesConc_HAC       (time, lev, lat, lon) float32 ...
#     SpeciesConc_H2O2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_H2O       (time, lev, lat, lon) float32 ...
#     SpeciesConc_H2402     (time, lev, lat, lon) float32 ...
#     SpeciesConc_H1301     (time, lev, lat, lon) float32 ...
#     SpeciesConc_H1211     (time, lev, lat, lon) float32 ...
#     SpeciesConc_GLYX      (time, lev, lat, lon) float32 ...
#     SpeciesConc_GLYC      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ETP       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ETNO3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ETHLN     (time, lev, lat, lon) float32 ...
#     SpeciesConc_EOH       (time, lev, lat, lon) float32 ...
#     SpeciesConc_DST4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_DST3      (time, lev, lat, lon) float32 ...
#     SpeciesConc_DST2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_DST1      (time, lev, lat, lon) float32 ...
#     SpeciesConc_DMS       (time, lev, lat, lon) float32 ...
#     SpeciesConc_CO        (time, lev, lat, lon) float32 ...
#     SpeciesConc_ClOO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ClO       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ClNO3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ClNO2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_Cl2O2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_Cl2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_Cl        (time, lev, lat, lon) float32 ...
#     SpeciesConc_CHCl3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CHBr3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH4       (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH3I      (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH3Cl     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH3CCl3   (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH3Br     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2O      (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2ICl    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2IBr    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2I2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2Cl2    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2Br2    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CFC12     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CFC115    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CFC114    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CFC113    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CFC11     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CCl4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_C3H8      (time, lev, lat, lon) float32 ...
#     SpeciesConc_C2H6      (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrSALC    (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrSALA    (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrO       (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrNO3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrNO2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrCl      (time, lev, lat, lon) float32 ...
#     SpeciesConc_Br2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_Br        (time, lev, lat, lon) float32 ...
#     SpeciesConc_BENZ      (time, lev, lat, lon) float32 ...
#     SpeciesConc_BCPO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_BCPI      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ATOOH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ALK4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ALD2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_AERI      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ACTA      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ACET      (time, lev, lat, lon) float32 ...
# Attributes:
#     title:                           GEOS-Chem diagnostic collection: Species...
#     history:
#     format:                          CFIO
#     conventions:                     COARDS
#     ProdDateTime:
#     reference:                       www.geos-chem.org; wiki.geos-chem.org
#     contact:                         GEOS-Chem Support Team (geos-chem-suppor...
#     simulation_start_date_and_time:  2016-01-01 00:00:00z
#     simulation_end_date_and_time:    2016-02-01 00:00:00z

# %%
devdata
# Out:
# <xarray.Dataset>
# Dimensions:               (ilev: 73, lat: 46, lev: 72, lon: 72, time: 1)
# Coordinates:
#   * time                  (time) datetime64[ns] 2016-01-16T12:00:00
#   * lev                   (lev) float64 0.9925 0.9775 ... 2.635e-05 1.5e-05
#   * ilev                  (ilev) float64 1.0 0.985 0.97 ... 3.27e-05 2e-05 1e-05
#   * lat                   (lat) float64 -89.0 -86.0 -82.0 ... 82.0 86.0 89.0
#   * lon                   (lon) float64 -180.0 -175.0 -170.0 ... 170.0 175.0
# Data variables:
#     hyam                  (lev) float64 ...
#     hybm                  (lev) float64 ...
#     hyai                  (ilev) float64 ...
#     hybi                  (ilev) float64 ...
#     P0                    float64 ...
#     AREA                  (lat, lon) float32 ...
#     SpeciesConc_RCOOH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_O2        (time, lev, lat, lon) float32 ...
#     SpeciesConc_N2        (time, lev, lat, lon) float32 ...
#     SpeciesConc_H2        (time, lev, lat, lon) float32 ...
#     SpeciesConc_O         (time, lev, lat, lon) float32 ...
#     SpeciesConc_HO2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_OH        (time, lev, lat, lon) float32 ...
#     SpeciesConc_O1D       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MO2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCO3      (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2OO     (time, lev, lat, lon) float32 ...
#     SpeciesConc_B3O2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_R4O2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_OTHRO2    (time, lev, lat, lon) float32 ...
#     SpeciesConc_ATO2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MACRNO2   (time, lev, lat, lon) float32 ...
#     SpeciesConc_INO2B     (time, lev, lat, lon) float32 ...
#     SpeciesConc_INO2D     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHOO1     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHOO4     (time, lev, lat, lon) float32 ...
#     SpeciesConc_A3O2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDHNBOO   (time, lev, lat, lon) float32 ...
#     SpeciesConc_PIO2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH3CHOO   (time, lev, lat, lon) float32 ...
#     SpeciesConc_IEPOXBOO  (time, lev, lat, lon) float32 ...
#     SpeciesConc_IEPOXAOO  (time, lev, lat, lon) float32 ...
#     SpeciesConc_KO2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_LIMO2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_RCO3      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHPNBOO   (time, lev, lat, lon) float32 ...
#     SpeciesConc_ETO2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_OLND      (time, lev, lat, lon) float32 ...
#     SpeciesConc_OLNN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PO2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MACR1OO   (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCROHOO   (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKOHOO   (time, lev, lat, lon) float32 ...
#     SpeciesConc_PRN1      (time, lev, lat, lon) float32 ...
#     SpeciesConc_R4N1      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ICHOO     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHPNDOO   (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHPOO3    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHPOO1    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHPOO2    (time, lev, lat, lon) float32 ...
#     SpeciesConc_H         (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDHNDOO2  (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDHNDOO1  (time, lev, lat, lon) float32 ...
#     SpeciesConc_ISOPNOO1  (time, lev, lat, lon) float32 ...
#     SpeciesConc_ROH       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ISOPNOO2  (time, lev, lat, lon) float32 ...
#     SpeciesConc_ICNOO     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDNOO     (time, lev, lat, lon) float32 ...
#     SpeciesConc_C4HVP2    (time, lev, lat, lon) float32 ...
#     SpeciesConc_C4HVP1    (time, lev, lat, lon) float32 ...
#     SpeciesConc_INA       (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPALD1OO  (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPALD2OO  (time, lev, lat, lon) float32 ...
#     SpeciesConc_XRO2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_N         (time, lev, lat, lon) float32 ...
#     SpeciesConc_TRO2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_BRO2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PH2O2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_LCH4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PSO4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_LCO       (time, lev, lat, lon) float32 ...
#     SpeciesConc_PCO       (time, lev, lat, lon) float32 ...
#     SpeciesConc_LOx       (time, lev, lat, lon) float32 ...
#     SpeciesConc_POx       (time, lev, lat, lon) float32 ...
#     SpeciesConc_SO4H4     (time, lev, lat, lon) float32 ...
#     SpeciesConc_SO4H3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_SO4H2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_SO4H1     (time, lev, lat, lon) float32 ...
#     SpeciesConc_LXRO2N    (time, lev, lat, lon) float32 ...
#     SpeciesConc_LXRO2H    (time, lev, lat, lon) float32 ...
#     SpeciesConc_LTRO2N    (time, lev, lat, lon) float32 ...
#     SpeciesConc_LTRO2H    (time, lev, lat, lon) float32 ...
#     SpeciesConc_LISOPNO3  (time, lev, lat, lon) float32 ...
#     SpeciesConc_LISOPOH   (time, lev, lat, lon) float32 ...
#     SpeciesConc_LBRO2N    (time, lev, lat, lon) float32 ...
#     SpeciesConc_LBRO2H    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CO2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_XYLE      (time, lev, lat, lon) float32 ...
#     SpeciesConc_TSOG3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_TSOG2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_TSOG1     (time, lev, lat, lon) float32 ...
#     SpeciesConc_TSOG0     (time, lev, lat, lon) float32 ...
#     SpeciesConc_TSOA3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_TSOA2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_TSOA1     (time, lev, lat, lon) float32 ...
#     SpeciesConc_TSOA0     (time, lev, lat, lon) float32 ...
#     SpeciesConc_TOLU      (time, lev, lat, lon) float32 ...
#     SpeciesConc_SOAS      (time, lev, lat, lon) float32 ...
#     SpeciesConc_SOAP      (time, lev, lat, lon) float32 ...
#     SpeciesConc_SOAIE     (time, lev, lat, lon) float32 ...
#     SpeciesConc_SOAGX     (time, lev, lat, lon) float32 ...
#     SpeciesConc_SO4s      (time, lev, lat, lon) float32 ...
#     SpeciesConc_SO4       (time, lev, lat, lon) float32 ...
#     SpeciesConc_SO2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_SALCCL    (time, lev, lat, lon) float32 ...
#     SpeciesConc_SALCAL    (time, lev, lat, lon) float32 ...
#     SpeciesConc_SALC      (time, lev, lat, lon) float32 ...
#     SpeciesConc_SALACL    (time, lev, lat, lon) float32 ...
#     SpeciesConc_SALAAL    (time, lev, lat, lon) float32 ...
#     SpeciesConc_SALA      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RP        (time, lev, lat, lon) float32 ...
#     SpeciesConc_RIPD      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RIPC      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RIPB      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RIPA      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RCHO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RB3P      (time, lev, lat, lon) float32 ...
#     SpeciesConc_RA3P      (time, lev, lat, lon) float32 ...
#     SpeciesConc_R4P       (time, lev, lat, lon) float32 ...
#     SpeciesConc_R4N2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PYAC      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PRPN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PRPE      (time, lev, lat, lon) float32 ...
#     SpeciesConc_PROPNN    (time, lev, lat, lon) float32 ...
#     SpeciesConc_PPN       (time, lev, lat, lon) float32 ...
#     SpeciesConc_PP        (time, lev, lat, lon) float32 ...
#     SpeciesConc_PIP       (time, lev, lat, lon) float32 ...
#     SpeciesConc_pFe       (time, lev, lat, lon) float32 ...
#     SpeciesConc_PAN       (time, lev, lat, lon) float32 ...
#     SpeciesConc_OIO       (time, lev, lat, lon) float32 ...
#     SpeciesConc_OCS       (time, lev, lat, lon) float32 ...
#     SpeciesConc_OCPO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_OCPI      (time, lev, lat, lon) float32 ...
#     SpeciesConc_OClO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_O3        (time, lev, lat, lon) float32 ...
#     SpeciesConc_NPRNO3    (time, lev, lat, lon) float32 ...
#     SpeciesConc_NO3       (time, lev, lat, lon) float32 ...
#     SpeciesConc_NO2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_NO        (time, lev, lat, lon) float32 ...
#     SpeciesConc_NITs      (time, lev, lat, lon) float32 ...
#     SpeciesConc_NIT       (time, lev, lat, lon) float32 ...
#     SpeciesConc_NH4       (time, lev, lat, lon) float32 ...
#     SpeciesConc_NH3       (time, lev, lat, lon) float32 ...
#     SpeciesConc_N2O5      (time, lev, lat, lon) float32 ...
#     SpeciesConc_N2O       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKPC     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKHP     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKHCB    (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKHC     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVKDH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MVK       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MTPO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MTPA      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MSA       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MPN       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MPAN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MP        (time, lev, lat, lon) float32 ...
#     SpeciesConc_MONITU    (time, lev, lat, lon) float32 ...
#     SpeciesConc_MONITS    (time, lev, lat, lon) float32 ...
#     SpeciesConc_MONITA    (time, lev, lat, lon) float32 ...
#     SpeciesConc_MOH       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MGLY      (time, lev, lat, lon) float32 ...
#     SpeciesConc_MENO3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MEK       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCRHP     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCRHNB    (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCRHN     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCRENOL   (time, lev, lat, lon) float32 ...
#     SpeciesConc_MCRDH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_MAP       (time, lev, lat, lon) float32 ...
#     SpeciesConc_MACR1OOH  (time, lev, lat, lon) float32 ...
#     SpeciesConc_MACR      (time, lev, lat, lon) float32 ...
#     SpeciesConc_LVOCOA    (time, lev, lat, lon) float32 ...
#     SpeciesConc_LVOC      (time, lev, lat, lon) float32 ...
#     SpeciesConc_LIMO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ITHN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ITCN      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ISOP      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ISALC     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ISALA     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IPRNO3    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IONO2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IONO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IONITA    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IO        (time, lev, lat, lon) float32 ...
#     SpeciesConc_INPD      (time, lev, lat, lon) float32 ...
#     SpeciesConc_INPB      (time, lev, lat, lon) float32 ...
#     SpeciesConc_INO       (time, lev, lat, lon) float32 ...
#     SpeciesConc_INDIOL    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHN4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHN3      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHN2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IHN1      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IEPOXD    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IEPOXB    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IEPOXA    (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDN       (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDHPE     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDHDP     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDCHP     (time, lev, lat, lon) float32 ...
#     SpeciesConc_IDC       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ICPDH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ICN       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ICl       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ICHE      (time, lev, lat, lon) float32 ...
#     SpeciesConc_IBr       (time, lev, lat, lon) float32 ...
#     SpeciesConc_I2O4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_I2O3      (time, lev, lat, lon) float32 ...
#     SpeciesConc_I2O2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_I2        (time, lev, lat, lon) float32 ...
#     SpeciesConc_I         (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPETHNL   (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPALD4    (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPALD3    (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPALD2    (time, lev, lat, lon) float32 ...
#     SpeciesConc_HPALD1    (time, lev, lat, lon) float32 ...
#     SpeciesConc_HONIT     (time, lev, lat, lon) float32 ...
#     SpeciesConc_HOI       (time, lev, lat, lon) float32 ...
#     SpeciesConc_HOCl      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HOBr      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HNO4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HNO3      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HNO2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HMML      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HMHP      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HI        (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCOOH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCl       (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCFC22    (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCFC142b  (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCFC141b  (time, lev, lat, lon) float32 ...
#     SpeciesConc_HCFC123   (time, lev, lat, lon) float32 ...
#     SpeciesConc_HC5A      (time, lev, lat, lon) float32 ...
#     SpeciesConc_HBr       (time, lev, lat, lon) float32 ...
#     SpeciesConc_HAC       (time, lev, lat, lon) float32 ...
#     SpeciesConc_H2O2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_H2O       (time, lev, lat, lon) float32 ...
#     SpeciesConc_H2402     (time, lev, lat, lon) float32 ...
#     SpeciesConc_H1301     (time, lev, lat, lon) float32 ...
#     SpeciesConc_H1211     (time, lev, lat, lon) float32 ...
#     SpeciesConc_GLYX      (time, lev, lat, lon) float32 ...
#     SpeciesConc_GLYC      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ETP       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ETNO3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ETHLN     (time, lev, lat, lon) float32 ...
#     SpeciesConc_EOH       (time, lev, lat, lon) float32 ...
#     SpeciesConc_DST4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_DST3      (time, lev, lat, lon) float32 ...
#     SpeciesConc_DST2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_DST1      (time, lev, lat, lon) float32 ...
#     SpeciesConc_DMS       (time, lev, lat, lon) float32 ...
#     SpeciesConc_CO        (time, lev, lat, lon) float32 ...
#     SpeciesConc_ClOO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ClO       (time, lev, lat, lon) float32 ...
#     SpeciesConc_ClNO3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ClNO2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_Cl2O2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_Cl2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_Cl        (time, lev, lat, lon) float32 ...
#     SpeciesConc_CHCl3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CHBr3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH4       (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH3I      (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH3Cl     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH3CCl3   (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH3Br     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2O      (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2ICl    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2IBr    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2I2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2Cl2    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CH2Br2    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CFC12     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CFC115    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CFC114    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CFC113    (time, lev, lat, lon) float32 ...
#     SpeciesConc_CFC11     (time, lev, lat, lon) float32 ...
#     SpeciesConc_CCl4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_C3H8      (time, lev, lat, lon) float32 ...
#     SpeciesConc_C2H6      (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrSALC    (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrSALA    (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrO       (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrNO3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrNO2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_BrCl      (time, lev, lat, lon) float32 ...
#     SpeciesConc_Br2       (time, lev, lat, lon) float32 ...
#     SpeciesConc_Br        (time, lev, lat, lon) float32 ...
#     SpeciesConc_BENZ      (time, lev, lat, lon) float32 ...
#     SpeciesConc_BCPO      (time, lev, lat, lon) float32 ...
#     SpeciesConc_BCPI      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ATOOH     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ASOG3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ASOG2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ASOG1     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ASOAN     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ASOA3     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ASOA2     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ASOA1     (time, lev, lat, lon) float32 ...
#     SpeciesConc_ALK4      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ALD2      (time, lev, lat, lon) float32 ...
#     SpeciesConc_AERI      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ACTA      (time, lev, lat, lon) float32 ...
#     SpeciesConc_ACET      (time, lev, lat, lon) float32 ...
# Attributes:
#     title:                           GEOS-Chem diagnostic collection: Species...
#     history:
#     format:                          CFIO
#     conventions:                     COARDS
#     ProdDateTime:
#     reference:                       www.geos-chem.org; wiki.geos-chem.org
#     contact:                         GEOS-Chem Support Team (geos-chem-suppor...
#     simulation_start_date_and_time:  2016-01-01 00:00:00z
#     simulation_end_date_and_time:    2016-02-01 00:00:00z

# %% [markdown]
# ### If using binary data, process it further

# %%
# Reorder the dimensions in the array to always be time, lev, lat, lon (so same order as netcdf)
# NOTE: check dimensions in refdata in previous step. Make sure they are all here and there are no extra.
if 'bpch' in comparison:
    refdata = refdata.transpose('lev','lev_edge','lat', 'lon') 
if comparison == 'bpch':
    devdata = devdata.transpose('lev','lev_edge','lat', 'lon')

# %%
# convert binary names to analogous netcdf diagnostic names
# NOTE: not necessary if comparing bpch vs bpch and not doing an official GEOS-Chem benchmark
if 'bpch' in comparison:
    refdata = gcpy.convert_bpch_names_to_netcdf_names(refdata)    
if comparison == 'bpch':
    devdata = gcpy.convert_bpch_names_to_netcdf_names(devdata)

# %%
# Change the units for concentrations. If ppb or ppbv then change to mol/mol. Will need to do this for
# other binary diagnostic units if they are not the same as netcdf. Ideally put the mapping in a dictionary.
conc_units = ['ppb','ppbv']
if 'bpch' in comparison:
    for var in refdata.data_vars:
        if refdata[var].units.strip() in conc_units:
            refdata[var].attrs['units'] = 'mol mol-1 dry'
            refdata[var].values = refdata[var].values * 1e-9
if comparison == 'bpch':
    for var in refdata.data_vars:
        if devdata[var].units.strip() in conc_units:
            devdata[var].attrs['units'] = 'mol mol-1 dry'
            devdata[var].values = devdata[var].values * 1e-9

# %% [markdown]
# ### Inspect common variables in ref and dev
# If you are comparing binary and netcdf diagnostics then you can expect a large number of variables with different names.

# %%
[cmnvars, cmnvarsOther, cmnvars2D, cmnvars3D] = gcpy.compare_varnames(refdata, devdata)
# Out:
# Comparing variable names in compare_varnames
# 205 common variables
# 0 variables in ref only
# 100 variables in dev only (skip)
#    Variable names: ['SpeciesConc_RCOOH', 'SpeciesConc_O2', 'SpeciesConc_N2', 'SpeciesConc_H2', 'SpeciesConc_O', 'SpeciesConc_HO2', 'SpeciesConc_OH', 'SpeciesConc_O1D', 'SpeciesConc_MO2', 'SpeciesConc_MCO3', 'SpeciesConc_CH2OO', 'SpeciesConc_B3O2', 'SpeciesConc_R4O2', 'SpeciesConc_OTHRO2', 'SpeciesConc_ATO2', 'SpeciesConc_MACRNO2', 'SpeciesConc_INO2B', 'SpeciesConc_INO2D', 'SpeciesConc_IHOO1', 'SpeciesConc_IHOO4', 'SpeciesConc_A3O2', 'SpeciesConc_IDHNBOO', 'SpeciesConc_PIO2', 'SpeciesConc_CH3CHOO', 'SpeciesConc_IEPOXBOO', 'SpeciesConc_IEPOXAOO', 'SpeciesConc_KO2', 'SpeciesConc_LIMO2', 'SpeciesConc_RCO3', 'SpeciesConc_IHPNBOO', 'SpeciesConc_ETO2', 'SpeciesConc_OLND', 'SpeciesConc_OLNN', 'SpeciesConc_PO2', 'SpeciesConc_MACR1OO', 'SpeciesConc_MCROHOO', 'SpeciesConc_MVKOHOO', 'SpeciesConc_PRN1', 'SpeciesConc_R4N1', 'SpeciesConc_ICHOO', 'SpeciesConc_IHPNDOO', 'SpeciesConc_IHPOO3', 'SpeciesConc_IHPOO1', 'SpeciesConc_IHPOO2', 'SpeciesConc_H', 'SpeciesConc_IDHNDOO2', 'SpeciesConc_IDHNDOO1', 'SpeciesConc_ISOPNOO1', 'SpeciesConc_ROH', 'SpeciesConc_ISOPNOO2', 'SpeciesConc_ICNOO', 'SpeciesConc_IDNOO', 'SpeciesConc_C4HVP2', 'SpeciesConc_C4HVP1', 'SpeciesConc_INA', 'SpeciesConc_HPALD1OO', 'SpeciesConc_HPALD2OO', 'SpeciesConc_XRO2', 'SpeciesConc_N', 'SpeciesConc_TRO2', 'SpeciesConc_BRO2', 'SpeciesConc_PH2O2', 'SpeciesConc_LCH4', 'SpeciesConc_PSO4', 'SpeciesConc_LCO', 'SpeciesConc_PCO', 'SpeciesConc_LOx', 'SpeciesConc_POx', 'SpeciesConc_SO4H4', 'SpeciesConc_SO4H3', 'SpeciesConc_SO4H2', 'SpeciesConc_SO4H1', 'SpeciesConc_LXRO2N', 'SpeciesConc_LXRO2H', 'SpeciesConc_LTRO2N', 'SpeciesConc_LTRO2H', 'SpeciesConc_LISOPNO3', 'SpeciesConc_LISOPOH', 'SpeciesConc_LBRO2N', 'SpeciesConc_LBRO2H', 'SpeciesConc_CO2', 'SpeciesConc_TSOG3', 'SpeciesConc_TSOG2', 'SpeciesConc_TSOG1', 'SpeciesConc_TSOG0', 'SpeciesConc_TSOA3', 'SpeciesConc_TSOA2', 'SpeciesConc_TSOA1', 'SpeciesConc_TSOA0', 'SpeciesConc_SALCCL', 'SpeciesConc_SALCAL', 'SpeciesConc_SALACL', 'SpeciesConc_SALAAL', 'SpeciesConc_ASOG3', 'SpeciesConc_ASOG2', 'SpeciesConc_ASOG1', 'SpeciesConc_ASOAN', 'SpeciesConc_ASOA3', 'SpeciesConc_ASOA2', 'SpeciesConc_ASOA1']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-68216e6b469c> in <module>
# ----> 1 [cmnvars, cmnvarsOther, cmnvars2D, cmnvars3D] = gcpy.compare_varnames(refdata, devdata)
#
# ValueError: too many values to unpack (expected 4)

# %% [markdown]
# ## Set and ref and dev strings for including in plots

# %%
refstr='GCC EPA2016 netcdf, 12.9.3' # EDIT AS NEEDED
devstr='GCC NEI2011 netcdf, 12.9.3' # EDIT AS NEEDED
    
print('Ref: {}'.format(refstr))
print('Dev: {}'.format(devstr))
# Out:
# Ref: GCC EPA2016 netcdf, 12.9.3
# Dev: GCC NEI2011 netcdf, 12.9.3

# %% [markdown]
# ## Compare species concentrations

# %% [markdown]
# ### Define list of variables to plot

# %%
#------------ Below are a few examples ---------------

# Example 1: all species
#desc='spc_conc'
#varlist = [k for k in cmnvars if 'SpeciesConc_' in k]

# Example 2: Subset of species
#desc='Dust'
#varlist = [k for k in cmnvars if 'DST' in k and 'SpeciesConc' in k]

# Example 3: one species
desc='Ozone'
varlist = ['SpeciesConc_NO']

print('{} variables found'.format(len(varlist)))
varlist
# Out:
# 1 variables found
# ['SpeciesConc_NO']

# %% [markdown]
# ### Inspect units to make sure they match (they might not if binary versus netcdf)

# %%
for var in varlist:
    print(var)
    print('   ref units: {}'.format(refdata[var].units))
    print('   dev units: {}'.format(devdata[var].units))
# Out:
# SpeciesConc_NO
#    ref units: mol mol-1 dry
#    dev units: mol mol-1 dry

# %%
# If units do not match, the following code may be helpful:
#
# Print all unique units in bpch datasets
# unitstrs = []
# for var in refdata.data_vars:
#     if refdata[var].units.strip() not in unitstrs:
#         unitstrs.append(refdata[var].units.strip())
# unitstrs

# %% [markdown]
# ### Plot inline in notebook
# If you use this function in ipython then import matplotlib.pyplot as plt and do plt.show() to create pop-up with figure.

# %%
# Try hovering over function name and pressing shift-tab to see optional arguments lst 
# NOTE: cmpres argument is only for when ref and dev grid resolutions differ
gcpy.compare_single_level( refdata, refstr, devdata, devstr, cmpres='1x1.25', varlist=['SpeciesConc_NO'])
# Out:
# Reuse existing file: ./conservative_4.0x5.0_1x1.25.nc
# Reuse existing file: ./conservative_4.0x5.0_1x1.25.nc

# %%
# Zonal mean - quick plot
gcpy.compare_zonal_mean( refdata, refstr, devdata, devstr, varlist=['SpeciesConc_NO'])

# %% [markdown]
# ### Send plots to PDF
# If you want to a create a pdf with more than one species then redefine varlist prior to passing to plot functions.

# %%
# This directory must already exist
plotsdir = '/path/to/plots/directory'

# %%
# Surface - PDF
pdfname = os.path.join(plotsdir,'{}_surface_{}_diag.pdf'.format(desc,comparison))
gcpy.compare_single_level( refdata, refstr, devdata, devstr, varlist=varlist, pdfname=pdfname )
gcpy.add_bookmarks_to_pdf( pdfname, varlist, remove_prefix='SpeciesConc_')
# Out:
# Reuse existing file: ./conservative_4x5_1x1.25.nc
# Reuse existing file: ./conservative_c24_1x1.25_0.nc
# Reuse existing file: ./conservative_c24_1x1.25_1.nc
# Reuse existing file: ./conservative_c24_1x1.25_2.nc
# Reuse existing file: ./conservative_c24_1x1.25_3.nc
# Reuse existing file: ./conservative_c24_1x1.25_4.nc
# Reuse existing file: ./conservative_c24_1x1.25_5.nc
#
# Creating /Users/lizzielundgren/gc/data/12.2.0_test/plots/Ozone_surface_bpch_vs_nc_diag.pdf for 1 variables
# 0

# %%
# Zonal mean - PDF
pdfname = os.path.join(plotsdir,'{}_zonalmean_{}_diag.pdf'.format(desc, comparison))
gcpy.compare_zonal_mean( refdata, refstr, devdata, devstr, varlist=varlist, pdfname=pdfname )
gcpy.add_bookmarks_to_pdf( pdfname, varlist, remove_prefix='SpeciesConc_')
# Out:
# Reuse existing file: ./conservative_4x5_1x1.25.nc
# Reuse existing file: ./conservative_c24_1x1.25_0.nc
# Reuse existing file: ./conservative_c24_1x1.25_1.nc
# Reuse existing file: ./conservative_c24_1x1.25_2.nc
# Reuse existing file: ./conservative_c24_1x1.25_3.nc
# Reuse existing file: ./conservative_c24_1x1.25_4.nc
# Reuse existing file: ./conservative_c24_1x1.25_5.nc
#
# Creating /Users/lizzielundgren/gc/data/12.2.0_test/plots/Ozone_zonalmean_bpch_vs_nc_diag.pdf for 1 variables
# 0

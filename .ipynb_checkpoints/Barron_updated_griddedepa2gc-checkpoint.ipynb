# %% [markdown]
# # Preparation of GEOS-Chem Emissions from CMAQ
#
#     author: Barron H. Henderson
#     contributors: Lyssa Freese. Adding names pending approval...
#     date: 2020-06-04

# %% [markdown]
# # Overview
#
# This notebook takes SMOKE outputs, which are CMAQ-ready emissions and converts them for use in GEOS-Chem. The tutorial uses "gridded reports", which contain annual data.  To make this operational, you instead repeat the process for each month.
#
# Steps:
# 1. install libraries
# 2. Download data from EPA
# 3. Regrid and convert to fluxes in GEOS-Chem format

# %% [markdown]
# # Install Libraries
#
# System Package | Use                   | Python Package | Use
# ---------------|-----------------------| ---------------|---------
# libgeos-dev    | Geospatial processing | basemap        | Mapping
# cdo            | Conservative regrid   | PseudoNetCDF   | IOAPI-like support
#
#
# * Run the next three cells

# %%
from cdo import Cdo
cdo = Cdo()
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mc
import PseudoNetCDF as pnc
from calendar import monthrange
import pandas as pd
os.environ['IOAPI_ISPH'] = '6370000.'

# %% [markdown]
# !apt-get install -qq libgeos-dev

# %% [markdown]
# %%capture
# !apt-get install -qq cdo

# %% [markdown]
# !pip install -q https://github.com/matplotlib/basemap/archive/master.zip
# !pip install -q https://github.com/barronh/pseudonetcdf/archive/master.zip

# %% [markdown]
# # Restart the Runtime
#
#   * choose the "Runtime" menu, and
#   * then "Restart Runtime"

# %% [markdown]
# # Import Libraries and Set Earth Radius
#
# * Importing necessary libraries
# * Setting IOAPI earth radius to WRF radius

# %% [markdown]
# # Download Files from EPA's newftp
#
# * Downloading inline and gridded anthropogenic emissions
# * Downloading biogenic and non-US sectors separately
#
# Note: if failing, remove `-q` to see errros.

# %%
areaonly_sectors = sectors = [
  'afdust_adj', 'ag', 'airports',
  'nonpt', 'nonroad', 'np_oilgas', 'onroad', 'onroad_ca_adj', 'rail', 'rwc', # domestic
]
intl_sectors = [
  'onroad_can', 'onroad_mex', 'othafdust_adj', 'othar', 'othptdust_adj', 'emln_othpt', # other countries (Can/Mex)
]

natural_sectors = [
  'ocean_cl2', 'beis',
  'emln_ptagfire', 'emln_ptfire', 'emln_ptfire_othna' # fires include some anthro
]
merged_sectors = [
  'mrggrid_nobeis_norwc', # sum of areaonly_sectors and allinln - partinln sectors
]

ptonly_sectors = ['emln_cmv_c1c2_12', 'emln_cmv_c3_12', 'emln_ptegu']

allinln_sectors = [
  'emln_pt_oilgas_allinln',
  'emln_ptnonipm_allinln',
]

partinln_sectors = [
  'emln_pt_oilgas',
  'emln_ptnonipm',
]

download_sectors = areaonly_sectors + ptonly_sectors + allinln_sectors + partinln_sectors + merged_sectors + intl_sectors + natural_sectors

# Not including natural because it would duplicate
# GEOS-Chem MEGAN, ocean, and fires
# Should cmv_c1_c2 be in? cmv_c3?
# airports?
include_sectors = areaonly_sectors + ptonly_sectors + allinln_sectors + intl_sectors

# %%
month = '01'
mon3c = pd.to_datetime('2016-{}-01'.format(month)).strftime('%b').lower()
filetmpl = "{dir}/2016fh_16j_{{sector}}_{dom}_month_{{month}}.ncf".format
smoketmpl = filetmpl(dir='input', dom='12US1').format
hemcotmpl = filetmpl(dir='output', dom='0pt1degree').format
urltmpl = filetmpl(dir="ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF/", dom='12US1').format

# %%
os.makedirs('input', exist_ok=True)
for sector in download_sectors:
  outpath = smoketmpl(sector=sector, month=month)
  url = urltmpl(sector=sector, month=month)
  print(url)
  os.system(f"wget -O {outpath}  --continue -q {url}")

os.system(f"wget --continue -q ftp://newftp.epa.gov/aqmg/global/gadm/gadm36_12US1.IOAPI.nc")
# Out:
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_afdust_adj_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_ag_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_airports_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_nonpt_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_nonroad_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_np_oilgas_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_onroad_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_onroad_ca_adj_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_rail_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_rwc_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_cmv_c1c2_12_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_cmv_c3_12_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_ptegu_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_pt_oilgas_allinln_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_ptnonipm_allinln_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_pt_oilgas_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_ptnonipm_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_mrggrid_nobeis_norwc_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_onroad_can_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_onroad_mex_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_othafdust_adj_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_othar_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_othptdust_adj_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_othpt_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_ocean_cl2_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_beis_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_ptagfire_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_ptfire_12US1_month_01.ncf
# ftp://newftp.epa.gov/Air/emismod/2016/v1/gridded/monthly_netCDF//2016fh_16j_emln_ptfire_othna_12US1_month_01.ncf
# 0

# %% [markdown]
# # Opening Files For Reading And Plotting

# %%
smokepaths = {
    sector: smoketmpl(sector=sector, month=month)
    for sector in include_sectors + natural_sectors
}
smokefiles = {
    sector: pnc.pncopen(path, format='ioapi', mode='r')
    for sector, path in smokepaths.items()
}

reffile = smokefiles[include_sectors[0]]

# %% [markdown]
# # Store Grid Parameters for Later Use
#
# * Regridding requires knowing about the grid structure
# * We are pulling all the metadata, so that we can use what we need.

# %%
gridproperties = reffile.getncatts()
exec('nominalarea = XCELL * YCELL', None, gridproperties)
exec('false_easting = -XORIG', None, gridproperties)
exec('false_northing = -YORIG', None, gridproperties)
exec('gridsize = NCOLS * NROWS', None, gridproperties)

# %% [markdown]
# # Creating Custom Merge files
#
# * Disabling warnings
#   * warns that  variables missing in the right hand file
#   * and are simply copied from the first file.
# * We don't need to see that.

# %%
def combine(f1, f2):
  """
  Arguments
  ---------
  f1 : netcdf-like object
    left-hand side of combine
  f2 : netcdf-like object
    right-hand side of combine

  Returns
  -------
  outf : netcdf-like object
    has all variables from f2 added to f1. If a variable is in f2 but
    not f1, it is added
  
  Notes
  -----
  Warnings are about variables in f1 that are not in f2, so they are ignored
  """
  import warnings
  warnings.filterwarnings('ignore')

  outf = f1 + f2
  for k, v in f2.variables.items():
      if k not in outf.variables:
          outf.copyVariable(v, key=k)
  warnings.resetwarnings()
  return outf

def merge(files):
  """
  Arguments
  ---------
  files : iterable of netcdf-like files
    files to be combined

  Returns
  -------
  outf : netcdf-like object
    has all mass from all variables in all files
  """
  outf = files[0].copy()
  for othf in files[1:]:
    outf = combine(outf, othf)
    
  return outf

def merge_from_dict(source, keys, outpath):
  """
  Arguments
  ---------
  source : dictionary
    contains netcdf-like variables keyed by sector
  keys : iterable
    keys to use to get netcdf-like variables for merging
  outpath : str
    save the merged file to disk
  
  Returns
  -------
  None
  """
  if os.path.exists(outpath):
    os.remove(outpath)
  outf = merge([source[k] for k in keys])
  history = getattr(outf, 'HISTORY', '')
  history += '; ' + ' + '.join(keys)
  setattr(outf, 'HISTORY', history)
  ondisk = outf.save(outpath, verbose=0);
  ondisk.close()

# %%
outpath = smoketmpl(sector='merge_areaonly', month=month)
merge_from_dict(smokefiles, areaonly_sectors, outpath)

outpath = smoketmpl(sector='merge_point', month=month)
merge_from_dict(smokefiles, allinln_sectors + ptonly_sectors, outpath)

outpath = smoketmpl(sector='merge_intl', month=month)
merge_from_dict(smokefiles, intl_sectors, outpath)

outpath = smoketmpl(sector='merge_natural', month=month)
merge_from_dict(smokefiles, natural_sectors, outpath)

mergedfiles = {
    sector: pnc.pncopen(smoketmpl(sector=sector, month=month), format='ioapi', mode='r')
    for sector in ['merge_areaonly', 'merge_point', 'merge_intl', 'merge_natural']
}
outpath = smoketmpl(sector='merge', month=month)
merge_from_dict(mergedfiles, ['merge_areaonly', 'merge_point', 'merge_intl'], outpath)
mergedfiles['merge'] = pnc.pncopen(outpath, format='ioapi', mode='r')

# %% [markdown]
# # Create a Database of Sums
#
# This will be used later for checking regridded data

# %%
checkspc = 'NOX'
originalrate = {
  sector: smokefiles[sector].variables[checkspc][:].sum()
  for sector in include_sectors if checkspc in smokefiles[sector].variables
}
mergedrate = {
    k: v.variables[checkspc][:].sum() for k, v in mergedfiles.items()
}

# %%
originalrate
# Out:
# {'airports': 13451.3545,
#  'nonpt': 97549.79,
#  'nonroad': 51478.305,
#  'np_oilgas': 50171.004,
#  'onroad': 270169.16,
#  'onroad_ca_adj': 15912.577,
#  'rail': 46735.008,
#  'rwc': 6970.175,
#  'emln_cmv_c1c2_12': 14105.198,
#  'emln_cmv_c3_12': 54651.74,
#  'emln_ptegu': 121331.41,
#  'emln_pt_oilgas_allinln': 32897.535,
#  'emln_ptnonipm_allinln': 79895.016,
#  'onroad_can': 30984.182,
#  'onroad_mex': 37089.695,
#  'othar': 54807.79,
#  'emln_othpt': 87304.69}

# %%
print(sum(originalrate.values()))
print(mergedrate)
# Out:
# 1065504.615234375
# {'merge_areaonly': 552437.4, 'merge_point': 302880.9, 'merge_intl': 210186.36, 'merge_natural': 71040.0, 'merge': 1065504.8}

# %% [markdown]
# # Comparing to US Report
#
# * Download reference report for comparison
# * This report contains US-only sectors
#   * for cmv and beis, the smoke files include areas outside the US
#   * The smoke files should always include more mass than the report.
#   * All other sectors in the monthly report should match.
# * Comparing US sectors excluding CMV, beis, and fire for total

# %%
os.system("wget --continue ftp://newftp.epa.gov/Air/emismod/2016/v1/reports/2016fh_county_monthly_report_22jan2020_v0.csv")
# Out:
# 0

# %%
monthlycounty = pd.read_csv('2016fh_county_monthly_report_22jan2020_v0.csv', comment='#')

# %%
monthlytotal = monthlycounty.groupby(['country_cd', 'census_tract_cd', 'poll']).sum().filter(like='_value').round(0)
spcmonthlytotal = monthlytotal.query('poll == "{}"'.format(checkspc)).copy()
for sector, rate in originalrate.items():
  sectork = sector.replace('emln_', '').replace('_allinln', '')
  key = ('US', sectork, checkspc)
  if key in spcmonthlytotal.index:
    spcmonthlytotal.loc[key, 'check'] = rate
  else:
    print('Skipping ', key, 'not in report')
spcmonthlytotal.round(0)
# Out:
# Skipping  ('US', 'onroad_can', 'NOX') not in report
# Skipping  ('US', 'onroad_mex', 'NOX') not in report
# Skipping  ('US', 'othar', 'NOX') not in report
# Skipping  ('US', 'othpt', 'NOX') not in report
#                                  ann_value  jan_value  feb_value  mar_value  \
# country_cd census_tract_cd poll
# US         airports        NOX    185194.0    13451.0    13597.0    15762.0
#            beis            NOX    965761.0    28927.0    38928.0    56449.0
#            cmv_c1c2_12     NOX    201072.0    12456.0    14152.0    15669.0
#            cmv_c3_12       NOX    622062.0    48633.0    47932.0    51287.0
#            nonpt           NOX    713202.0    97549.0    91792.0    59867.0
#            nonroad         NOX   1100139.0    51478.0    52693.0    81314.0
#            np_oilgas       NOX    573512.0    50171.0    42628.0    51402.0
#            onroad          NOX   3407410.0   270158.0   266572.0   291404.0
#            onroad_ca_adj   NOX    223138.0    15912.0    16461.0    18525.0
#            pt_oilgas       NOX    389019.0    32897.0    30776.0    32982.0
#            ptagfire        NOX     10238.0      432.0     1016.0     1098.0
#            ptegu           NOX   1290190.0   121331.0   102388.0    85839.0
#            ptfire          NOX    227369.0    10224.0    26589.0    42156.0
#            ptnonipm        NOX    942437.0    79895.0    74770.0    79278.0
#            rail            NOX    560903.0    46735.0    44131.0    45400.0
#            rwc             NOX     31497.0     6970.0     5446.0     3363.0
#
#                                  apr_value  may_value  jun_value  jul_value  \
# country_cd census_tract_cd poll
# US         airports        NOX     15839.0    16382.0    16420.0    16934.0
#            beis            NOX     99569.0   114731.0   123526.0   132614.0
#            cmv_c1c2_12     NOX     16248.0    17604.0    17955.0    18715.0
#            cmv_c3_12       NOX     50965.0    53089.0    50527.0    53994.0
#            nonpt           NOX     56249.0    57165.0    30553.0    31997.0
#            nonroad         NOX     86321.0   102366.0   133425.0   120846.0
#            np_oilgas       NOX     44412.0    47602.0    45928.0    46690.0
#            onroad          NOX    288538.0   290351.0   291337.0   285964.0
#            onroad_ca_adj   NOX     18511.0    18946.0    20370.0    20364.0
#            pt_oilgas       NOX     31918.0    32981.0    31834.0    32892.0
#            ptagfire        NOX      1071.0      587.0      457.0      456.0
#            ptegu           NOX     80860.0    87328.0   115640.0   140355.0
#            ptfire          NOX     28153.0     9127.0    10834.0    16295.0
#            ptnonipm        NOX     76732.0    79258.0    77251.0    79785.0
#            rail            NOX     44366.0    46735.0    45653.0    47175.0
#            rwc             NOX      2394.0     1007.0      412.0      434.0
#
#                                  aug_value  sep_value  oct_value  nov_value  \
# country_cd census_tract_cd poll
# US         airports        NOX     16802.0    15862.0    16474.0    14033.0
#            beis            NOX    117511.0    93098.0    74753.0    55329.0
#            cmv_c1c2_12     NOX     18512.0    17838.0    18395.0    16948.0
#            cmv_c3_12       NOX     53918.0    53287.0    56856.0    51315.0
#            nonpt           NOX     31843.0    52735.0    54339.0    52582.0
#            nonroad         NOX    121248.0    88332.0   108262.0    95827.0
#            np_oilgas       NOX     47455.0    49679.0    47677.0    50688.0
#            onroad          NOX    291623.0   276941.0   289889.0   278421.0
#            onroad_ca_adj   NOX     21302.0    19214.0    18986.0    17291.0
#            pt_oilgas       NOX     32895.0    31960.0    33025.0    31959.0
#            ptagfire        NOX       489.0     1205.0     1369.0     1522.0
#            ptegu           NOX    136017.0   111261.0   101622.0    89703.0
#            ptfire          NOX     25544.0    14051.0    15378.0    21765.0
#            ptnonipm        NOX     79827.0    77725.0    80313.0    77704.0
#            rail            NOX     49839.0    47370.0    49839.0    47370.0
#            rwc             NOX       350.0      502.0     1399.0     3024.0
#
#                                  dec_value     check
# country_cd census_tract_cd poll
# US         airports        NOX     13639.0   13451.0
#            beis            NOX     30327.0       NaN
#            cmv_c1c2_12     NOX     16581.0   14105.0
#            cmv_c3_12       NOX     50259.0   54652.0
#            nonpt           NOX     96531.0   97550.0
#            nonroad         NOX     58027.0   51478.0
#            np_oilgas       NOX     49179.0   50171.0
#            onroad          NOX    286212.0  270169.0
#            onroad_ca_adj   NOX     17255.0   15913.0
#            pt_oilgas       NOX     32898.0   32898.0
#            ptagfire        NOX       537.0       NaN
#            ptegu           NOX    117846.0  121331.0
#            ptfire          NOX      7253.0       NaN
#            ptnonipm        NOX     79900.0   79895.0
#            rail            NOX     46290.0   46735.0
#            rwc             NOX      6196.0    6970.0

# %%
reportmatch = (
    mergedrate['merge']
    - mergedrate['merge_intl'] - originalrate['emln_cmv_c1c2_12'] - originalrate['emln_cmv_c3_12']
)
reporttotal = spcmonthlytotal.query('census_tract_cd not in ("beis", "ptfire", "ptagfire", "cmv_c1c2_12", "cmv_c3_12")').sum()
print('Report without fire, beis, cmv')
print(reporttotal.round(0))
print ('\nFor comparing to report', reportmatch)
print('Ratio', reportmatch / reporttotal[mon3c + '_value'])
# Out:
# Report without fire, beis, cmv
# ann_value    9416641.0
# jan_value     786547.0
# feb_value     741254.0
# mar_value     765136.0
# apr_value     746140.0
# may_value     780121.0
# jun_value     808823.0
# jul_value     823436.0
# aug_value     829201.0
# sep_value     771581.0
# oct_value     801825.0
# nov_value     758602.0
# dec_value     803973.0
# check         786561.0
# dtype: float64
#
# For comparing to report 786561.44
# Ratio 1.0000183555464581

# %% [markdown]
# # Create Spatial Plots
#
# * Showing several aggregates on top
# * Components shown on bottom

# %%
key = 'NOX'
norm = mc.LogNorm(vmin=1e-1, vmax=1e3)
fig, axx = plt.subplots(2, 3, gridspec_kw=dict(hspace=.05, wspace=0.025), figsize=(10, 6))
cax = fig.add_axes([0.1, 0.05, .8, .025])
plotopt = dict(norm=norm)
cbaropt = dict(label='{} tons/year'.format(key), cax=cax, orientation='horizontal')
plt.sca(axx[0, 0])
mergedfiles['merge'].plot(key, plot_kw=plotopt, cbar_kw=cbaropt).set_xlabel('Total')
plt.sca(axx[0, 1])
mergedfiles['merge_point'].plot(key, plot_kw=plotopt, cbar_kw=cbaropt).set_xlabel('Point')
plt.sca(axx[0, 2])
mergedfiles['merge_areaonly'].plot(key, plot_kw=plotopt, cbar_kw=cbaropt).set_xlabel('Area')
plt.sca(axx[1, 0])
mergedfiles['merge_natural'].plot(key, plot_kw=plotopt, cbar_kw=cbaropt).set_xlabel('Natural')
plt.sca(axx[1, 1])
mergedfiles['merge_intl'].plot(key, plot_kw=plotopt, cbar_kw=cbaropt).set_xlabel('International')
axx[1, 2].set_visible(False)

# %% [markdown]
# # Prepare for Regridding By Defining Grids
#
# * EPA12US1.grid defines a Lambert Conic Conformal grid
# * latlon.grid defines a regional latitude/longitude grid
# * z.grid defines the first layer of GEOS-Chem's hybrid coordinate

# %%
lccpath = 'EPA12US1.grid'
llpath = 'latlon.grid'
with open(lccpath, mode='w') as gf:
  gf.write("""gridtype = projection
gridsize = {gridsize}
xsize = {NCOLS}
ysize = {NROWS}
xinc = {XCELL}
yinc = {YCELL}
xname = x
yname = y
grid_mapping_name = lambert_conformal_conic
latitude_of_projection_origin = {YCENT}
longitude_of_projection_origin = {XCENT}
longitude_of_central_meridian = {XCENT}
standard_parallel = {P_ALP}, {P_BET}
earth_radius = 6370000.
semi_major_axis = 6370000.
semi_minor_axis = 6370000.
false_easting = {false_easting}
false_northing = {false_northing}
""".format(**gridproperties))
  
with open(llpath, mode='w') as gf:
  gf.write("""gridtype  = lonlat
gridsize  = 360000
xsize     = 900
ysize     = 400
xname     = lon
xlongname = "longitude"
xunits    = "degrees_east"
yname     = lat
ylongname = "latitude"
yunits    = "degrees_north"
xfirst    = -139.95
xinc      = 0.1
yfirst    = 20.05
yinc      = 0.1
""")
  
with open('z1.grid', mode='w') as gf:
  gf.write("""zaxistype = hybrid 
size = 1
levels = 0
positive = "up"
long_name = "GEOS-Chem levels"
axis = "Z"
""")

# %% [markdown]
# # Initialize the CDO Library and Prepare Command
#
# * Initialization is easy
# * You may get a warning

# %%
from cdo import Cdo
cdo = Cdo()
# cdo.CDO = '/work/ROMO/anaconda3/envs/geo/bin/cdo

# %% [markdown]
# # Now Configure the CDO Command
#
# cmd has 5 parts (run and described in bottom-to-top order)
#
# * Set the vertical axis,
# * rename TSTEP axis to time, remove TFLAG, set the time
# * convert from tons/year to tons/s, tons/m2/s, then kg/m2/s
# * Set units to mass fluxes
# * Set grid to LCC and Regrid to the lon/lat grid

# %%
cmdtmpl = (
    '-remapycon,{llpath} -setgrid,{lccpath} ' + # assign LCC grid and regrid
    '-setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s ' + # fix units
    '-mulc,{unitconversion} -divc,{nominalarea} -divc,{seconds} ' + # convert tons/year to kg/m2/s
    '-setreftime,1970-01-01,00:00:00,hours -settaxis,2016-{month}-01,00:00:00 -delname,TFLAG -chname,TSTEP,time ' + # fix time properties
    '-setzaxis,z1.grid -chname,LAY,lev ' +
    '{inpath}' # fix dimensions
)

# %% [markdown]
# # Regrid Each file
#
# * Using cmd described above and applying 0 to missing values
# * Output
#   * NetCDF4
#   * grid chunking
#   * level 1 compressions

# %%
remakeall = False
fileopts = '-O -f nc4 -k grid -z zip_1'
os.makedirs('output', exist_ok=True)
options = dict(
  llpath=llpath, lccpath=lccpath, nominalarea=gridproperties['nominalarea'],
  unitconversion=907.185, month=month
)

cdo_sectors = include_sectors + list(mergedfiles)

for sector in cdo_sectors:
  inpath = smoketmpl(sector=sector, month=month)
  outpath = hemcotmpl(sector=sector, month=month)
  if os.path.exists(outpath) and not remakeall:
    print('Keeping cached:', outpath)
    continue
  else:
    print(outpath, end='', flush=True)
  f = pnc.pncopen(inpath, format='ioapi')
  sdate = f.getTimes()[0]
  ndays = monthrange(sdate.year, sdate.month)[1]
  options['seconds'] = ndays * 24 * 3600
  if os.path.exists(outpath):
    os.remove(outpath)
  cmd = cmdtmpl.format(inpath=inpath, **options)
  print(cmd,end='.')
  cdo.setmisstoc(0, input=cmd, output=outpath, options=fileopts)
  print('.done', flush=True)
print('Success: all complete')
# Out:
# output/2016fh_16j_afdust_adj_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_afdust_adj_12US1_month_01.ncf..done
# output/2016fh_16j_ag_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_ag_12US1_month_01.ncf..done
# output/2016fh_16j_airports_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_airports_12US1_month_01.ncf..done
# output/2016fh_16j_nonpt_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_nonpt_12US1_month_01.ncf..done
# output/2016fh_16j_nonroad_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_nonroad_12US1_month_01.ncf..done
# output/2016fh_16j_np_oilgas_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_np_oilgas_12US1_month_01.ncf..done
# output/2016fh_16j_onroad_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_onroad_12US1_month_01.ncf..done
# output/2016fh_16j_onroad_ca_adj_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_onroad_ca_adj_12US1_month_01.ncf..done
# output/2016fh_16j_rail_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_rail_12US1_month_01.ncf..done
# output/2016fh_16j_rwc_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_rwc_12US1_month_01.ncf..done
# output/2016fh_16j_emln_cmv_c1c2_12_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_emln_cmv_c1c2_12_12US1_month_01.ncf..done
# output/2016fh_16j_emln_cmv_c3_12_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_emln_cmv_c3_12_12US1_month_01.ncf..done
# output/2016fh_16j_emln_ptegu_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_emln_ptegu_12US1_month_01.ncf..done
# output/2016fh_16j_emln_pt_oilgas_allinln_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_emln_pt_oilgas_allinln_12US1_month_01.ncf..done
# output/2016fh_16j_emln_ptnonipm_allinln_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_emln_ptnonipm_allinln_12US1_month_01.ncf..done
# output/2016fh_16j_onroad_can_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_onroad_can_12US1_month_01.ncf..done
# output/2016fh_16j_onroad_mex_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_onroad_mex_12US1_month_01.ncf..done
# output/2016fh_16j_othafdust_adj_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_othafdust_adj_12US1_month_01.ncf..done
# output/2016fh_16j_othar_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_othar_12US1_month_01.ncf..done
# output/2016fh_16j_othptdust_adj_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_othptdust_adj_12US1_month_01.ncf..done
# output/2016fh_16j_emln_othpt_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_emln_othpt_12US1_month_01.ncf..done
# output/2016fh_16j_merge_areaonly_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_merge_areaonly_12US1_month_01.ncf..done
# output/2016fh_16j_merge_point_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_merge_point_12US1_month_01.ncf..done
# output/2016fh_16j_merge_intl_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_merge_intl_12US1_month_01.ncf..done
# output/2016fh_16j_merge_natural_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_merge_natural_12US1_month_01.ncf..done
# output/2016fh_16j_merge_0pt1degree_month_01.ncf-remapycon,latlon.grid -setgrid,EPA12US1.grid -setattribute,NOX@units=kgNO2/m2/s -setattribute,NO@units=kgNO2/m2/s -setattribute,*@units=kg/m2/s -mulc,907.185 -divc,144000000.0 -divc,2678400 -setreftime,1970-01-01,00:00:00,hours -settaxis,2016-01-01,00:00:00 -delname,TFLAG -chname,TSTEP,time -setzaxis,z1.grid -chname,LAY,lev input/2016fh_16j_merge_12US1_month_01.ncf..done
# Success: all complete

# %% [markdown]
# # Check Mass Conservation
#
# * Calculate the Mass from Regridded Fluxes
# * Get the Area of the New Grid
# * Convert to mass comparable to CMAQ
#   * Multiply the area by the fluxes
#   * Convert per second rates to per year
#   * Convert kg to short tons

# %%
areaf = cdo.gridarea(llpath, input='-remapnn,%s -stdatm,0' % llpath, options='-f nc4', returnCdf=True)
area = areaf.variables['cell_area'][:]

# %%
hemco2dfiles = {
  sector: pnc.pncopen(hemcotmpl(sector=sector, month=month), format='netcdf', mode='r')
  for sector in include_sectors
}

hemco2dmergedfiles = {
  sector: pnc.pncopen(hemcotmpl(sector=sector, month=month), format='netcdf', mode='r')
  for sector in list(mergedfiles)
}
hemco2drate = {}
for sector in include_sectors:
  sfile = hemco2dfiles[sector]
  if checkspc not in sfile.variables:
    continue
  sdate =  sfile.getTimes()[0]
  ndays = monthrange(sdate.year, sdate.month)[1]
  checkval = (sfile.variables[checkspc][:].sum((0, 1)) * area).sum() * ndays * 24 * 3600 * 0.00110231
  hemco2drate[sector] = checkval

hemco2dmergedrate = {}
for sector in list(mergedfiles):
  sfile = hemco2dmergedfiles[sector]
  if checkspc not in sfile.variables:
    continue
  sdate =  sfile.getTimes()[0]
  ndays = monthrange(sdate.year, sdate.month)[1]
  checkval = (sfile.variables[checkspc][:].sum((0, 1)) * area).sum() * ndays * 24 * 3600 * 0.00110231
  hemco2dmergedrate[sector] = checkval

# %%
hemco2dtotal = sum(hemco2drate.values())
hemco2dmergedtotal = (hemco2dmergedrate['merge_areaonly'] + hemco2dmergedrate['merge_point'] + hemco2dmergedrate['merge_intl'])
hemco2dreportmatch = (
    hemco2dmergedrate['merge']
    - hemco2dmergedrate['merge_intl'] - hemco2drate['emln_cmv_c1c2_12'] - hemco2drate['emln_cmv_c3_12']
)
print('Report without fire, beis, cmv')
print(reporttotal.round(0))
print ('\nFor comparing to report', hemco2dreportmatch)
print('Ratio', hemco2dreportmatch / reporttotal[mon3c + '_value'])

hemco2dtotal = sum(hemco2drate.values())
hemco2dmergedtotal = (hemco2dmergedrate['merge_areaonly'] + hemco2dmergedrate['merge_point'] + hemco2dmergedrate['merge_intl'])
print('ORIG', mergedrate['merge'])
print('HEMCO2D merged ar/pt/intl', hemco2dtotal)
print('HEMCO2D single merged', hemco2dmergedtotal)
print('ORIG/HEMCO2D', hemco2dtotal / mergedrate['merge'])
hemco2dmergedrate
# Out:
# Report without fire, beis, cmv
# ann_value    9416641.0
# jan_value     786547.0
# feb_value     741254.0
# mar_value     765136.0
# apr_value     746140.0
# may_value     780121.0
# jun_value     808823.0
# jul_value     823436.0
# aug_value     829201.0
# sep_value     771581.0
# oct_value     801825.0
# nov_value     758602.0
# dec_value     803973.0
# check         786561.0
# dtype: float64
#
# For comparing to report 789185.1343586212
# Ratio 1.0033540708420745
# ORIG 1065504.8
# HEMCO2D merged ar/pt/intl 1062222.45904068
# HEMCO2D single merged 1062222.459371407
# ORIG/HEMCO2D 0.9969194966429572
# {'merge_areaonly': 554318.6197205891,
#  'merge_point': 302869.94140724366,
#  'merge_intl': 205033.89824357416,
#  'merge_natural': 70699.1231149411,
#  'merge': 1062222.459654585}

# %%
for key in 'NOX APIN BPIN ISOP SESQ TERP'.split():
  for sector in include_sectors:
    sfile = hemco2dfiles[sector]
    if key not in sfile.variables:
        continue
    vals = sfile.variables[key][:]
    print('{}: {} sum={:.7g}'.format(sector, key, (vals * area).sum() * 3600 * 24 * 366 * 0.00110231))
# Out:
# airports: NOX sum=159122.9
# nonpt: NOX sum=1158309
# nonroad: NOX sum=608900.3
# np_oilgas: NOX sum=593596.4
# onroad: NOX sum=3198611
# onroad_ca_adj: NOX sum=189102.7
# rail: NOX sum=554221.6
# rwc: NOX sum=82672.46
# emln_cmv_c1c2_12: NOX sum=165388.9
# emln_cmv_c3_12: NOX sum=637490.2
# emln_ptegu: NOX sum=1439615
# emln_pt_oilgas_allinln: NOX sum=388395.3
# emln_ptnonipm_allinln: NOX sum=944929.5
# onroad_can: NOX sum=359206.3
# onroad_mex: NOX sum=427587
# othar: NOX sum=634091
# emln_othpt: NOX sum=999838.5
# ag: ISOP sum=152.9896
# airports: ISOP sum=1.127476
# nonpt: ISOP sum=199.7406
# nonroad: ISOP sum=1357.137
# np_oilgas: ISOP sum=1.238312
# onroad: ISOP sum=999.6573
# onroad_ca_adj: ISOP sum=42.21841
# rail: ISOP sum=46.20044
# rwc: ISOP sum=2777.98
# emln_cmv_c1c2_12: ISOP sum=63.46541
# emln_cmv_c3_12: ISOP sum=366.2024
# emln_ptegu: ISOP sum=0.9196998
# emln_pt_oilgas_allinln: ISOP sum=5.564373
# emln_ptnonipm_allinln: ISOP sum=707.52
# onroad_can: ISOP sum=29.79723
# onroad_mex: ISOP sum=79.6015
# othar: ISOP sum=2286.63
# emln_othpt: ISOP sum=93.3523
# ag: TERP sum=787.3592
# airports: TERP sum=0
# nonpt: TERP sum=43538.78
# nonroad: TERP sum=12.73065
# np_oilgas: TERP sum=0
# onroad: TERP sum=133.5332
# onroad_ca_adj: TERP sum=7.12297
# rail: TERP sum=35.88145
# rwc: TERP sum=0
# emln_cmv_c1c2_12: TERP sum=0
# emln_cmv_c3_12: TERP sum=0
# emln_ptegu: TERP sum=30.65837
# emln_pt_oilgas_allinln: TERP sum=11.21128
# emln_ptnonipm_allinln: TERP sum=36097.02
# onroad_can: TERP sum=21.90676
# onroad_mex: TERP sum=5.168052
# othar: TERP sum=17047.69
# emln_othpt: TERP sum=4952.301

# %% [markdown]
# # Plot Results
#
# * Always good to take a look at NOX
# * Showing 2D results
# * cmv c1, c2, c3 has international emissions, which explains the small emission masses in Canada.

# %%
spc = 'NOX'
fig, axx = plt.subplots(2, 2, gridspec_kw=dict(bottom=0.15))
cax = fig.add_axes([.1, .05, .8, .025])
plotopts=dict(norm=mc.LogNorm())
cbaropts = dict(cax=cax, orientation='horizontal')
plt.sca(axx[0, 0])
hemco2dmergedfiles['merge'].plot(spc, plottype='lon-lat', plot_kw=plotopts, cbar_kw=cbaropts)
axx[0, 0].set_ylabel("total")
plt.sca(axx[1, 0])
hemco2dmergedfiles['merge_areaonly'].plot(spc, plottype='lon-lat', plot_kw=plotopts, cbar_kw=cbaropts)
axx[1, 0].set_ylabel('Gridded')
plt.sca(axx[1, 1])
hemco2dmergedfiles['merge_point'].plot(spc, plottype='lon-lat', plot_kw=plotopts, cbar_kw=cbaropts)
axx[1, 1].set_ylabel('emln')
axx[1, 1].yaxis.set_label_position("right")
plt.sca(axx[0, 1])
hemco2dmergedfiles['merge_intl'].plot(spc, plottype='lon-lat', plot_kw=plotopts, cbar_kw=cbaropts)
axx[0, 1].set_ylabel('intl')
axx[0, 1].yaxis.set_label_position("right")
from mpl_toolkits.basemap import Basemap
bmap = Basemap(llcrnrlat=20, llcrnrlon=-137.5, urcrnrlat=60, urcrnrlon=-50, resolution='c')
for ax in axx.ravel():
  bmap.drawcoastlines(ax=ax)
  bmap.drawcountries(ax=ax)
# Out:
# **PNC:/home/emfreese/anaconda3/envs/conda_env/lib/python3.7/site-packages/PseudoNetCDF/pncwarn.py:24:UserWarning:
#   Bounds is an approximation assuming lon variable is cell centers
# **PNC:/home/emfreese/anaconda3/envs/conda_env/lib/python3.7/site-packages/PseudoNetCDF/pncwarn.py:24:UserWarning:
#   Bounds is an approximation assuming lat variable is cell centers
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-894bf3c76844> in <module>
#      18 axx[0, 1].set_ylabel('intl')
#      19 axx[0, 1].yaxis.set_label_position("right")
# ---> 20 from mpl_toolkits.basemap import Basemap
#      21 bmap = Basemap(llcrnrlat=20, llcrnrlon=-137.5, urcrnrlat=60, urcrnrlon=-50, resolution='c')
#      22 for ax in axx.ravel():
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %% [markdown]
# # Vertical Allocation Table
#
# * Oversimplifying vertical allocation
#   * Similar to Simpson et al. 2003 Table 4.1, we apply a single representative allocation to each sector.
#   * Simpson D., Fagerli, H., Jonson, J. E., Tsyro, S., Wind, P., and Tuovinen, J.: "Transboundary Acidification, Eutrophication, and Ground Level Ozone in Europe - Part I: Unified EMEP Model Description”, EMEP Status Report 2003, The  Norwegian Meteorological Institute, Oslo, 25 Norway, 2003. https://www.emep.int/publ/reports/2003/emep_report_1_part1_2003.pdf

# %%
import pandas as pd
import io

vertical_allocation = pd.read_csv(io.StringIO("""L,bottom_m,top_m,othpt,ptegu,ptnonipm,pt_oilgas,ptfire,cmv_c3
1,-6,123,0.806067059,0.027331187,0.751204553,0.918700528,0.11976381,0.537538889
2,123,254,0.087955253,0.12260809,0.144224191,0.059678397,0.098297847,0.338982929
3,254,387,0.053252808,0.192017292,0.052822078,0.013323237,0.08277491,0.123478182
4,387,521,0.025605531,0.212736741,0.023840537,0.003978944,0.074659995,0
5,521,657,0.011408677,0.167549199,0.011000364,0.001724366,0.077561337,0
6,657,795,0.005787852,0.110491495,0.005661267,0.001038275,0.073349589,0
7,795,934,0.003758579,0.063653198,0.003165207,0.000633395,0.066694526,0
8,934,1075,0.002673887,0.036979211,0.00197344,0.000387233,0.061845442,0
9,1075,1218,0.001675656,0.022844579,0.001300664,0.000243355,0.058324971,0
10,1218,1363,0.000670159,0.013909341,0.000861865,0.000122994,0.053902287,0
11,1363,1510,0.000357644,0.008781226,0.000621856,6.48583E-05,0.044774262,0
12,1510,1659,0.00022693,0.006647819,0.00052355,4.04985E-05,0.041122289,0
13,1659,1860,0.000159139,0.004305749,0.000466642,2.12041E-05,0.0306914,0
14,1860,2118,0.000152154,0.003380562,0.000680222,1.75333E-05,0.031529605,0
15,2118,2382,0.000113674,0.001827346,0.000612964,1.03278E-05,0.02551535,0
16,2382,2654,8.79442E-05,0.000957313,0.000260885,5.76406E-06,0.020748307,0
17,2654,2932,3.14778E-05,0.000523901,0.000311535,3.23215E-06,0.014366484,0
18,2932,3219,1.29957E-05,0.000381747,0.000231719,2.27428E-06,0.010906613,0
19,3219,3665,1.37334E-06,0.000409744,0.000115745,1.78044E-06,0.009224629,0
20,3665,4132,3.15633E-07,0.000340645,4.19637E-05,6.00909E-07,0.003409241,0
21,4132,4623,3.71912E-07,0.00026689,1.84353E-05,4.14262E-07,0.00014894,0
22,4623,5142,4.01952E-07,0.000231509,1.03385E-05,3.73296E-07,0.000125351,0
23,5142,5692,1.17457E-07,0.000225471,9.11318E-06,3.01765E-07,8.76892E-05,0
24,5692,6277,0,0.000310076,9.82452E-06,1.13299E-07,3.24343E-05,0
25,6277,6905,0,0.000327088,1.07925E-05,0,3.0049E-05,0
26,6905,7582,0,0.000260516,1.2311E-05,0,2.85539E-05,0
27,7582,8320,0,0.000130502,4.58591E-06,0,2.08973E-05,0
28,8320,9409,0,0.000119402,2.72213E-06,0,3.26732E-05,0
29,9409,10504,0,0.000106184,6.30588E-07,0,1.74394E-05,0
30,10504,11578,0,9.07766E-05,0,0,1.30783E-05,0
31,11578,12633,0,0.000117164,0,0,0,0
32,12633,13674,0,0.000122616,0,0,0,0
33,13674,14706,0,1.54213E-05,0,0,0,0
34,14706,15731,0,0,0,0,0,0
35,15731,16753,0,0,0,0,0,0
36,16753,17773,0,0,0,0,0,0
37,17773,19855,0,0,0,0,0,0
38,19855,22004,0,0,0,0,0,0
39,22004,24240,0,0,0,0,0,0
40,24240,26596,0,0,0,0,0,0
41,26596,31716,0,0,0,0,0,0
42,31716,37574,0,0,0,0,0,0
43,37574,44286,0,0,0,0,0,0
44,44286,51788,0,0,0,0,0,0
45,51788,59924,0,0,0,0,0,0
46,59924,68392,0,0,0,0,0,0
47,68392,80581,0,0,0,0,0,0
""")).set_index(['L'])

# %% [markdown]
# # Set a Maximum Number of Layers
#
# * Some layers have non-zero values up to layer 33
#   * This seems unreasonable.
#   * Simpson et al. 2003 had up to layer 11 in this vertical coordinate
# * Setting a maximum top layer of 11
#   * renormalizing mass within those 11 layers.

# %%
nl = 11
vertical_allocation_layers = vertical_allocation.loc[1:nl]
vertical_allocation_layer_fraction = vertical_allocation_layers / vertical_allocation_layers.sum()

# %% [markdown]
# # Apply Vertical Allocation
#
# * Map each smoke sector to a vertical allocation
# * Manually fixing meta data
#   * (hyai, hybi, and lev)
#   * renaming dimensions to ilev

# %%
import gc


sector2verticalallocation = {
  'emln_cmv_c1c2_12': 'cmv_c3',
  'emln_cmv_c3_12': 'cmv_c3',
  'emln_othpt': 'othpt',
  'emln_pt_oilgas_allinln': 'pt_oilgas',
  'emln_ptegu': 'ptegu',
  'emln_ptnonipm_allinln': 'ptnonipm'
}

for sector in ptonly_sectors + allinln_sectors:
  gc.collect()
  inpath = hemcotmpl(sector=sector, month=month)
  outpath = inpath.replace('0pt1degree', '0pt1degree_3D')
  origlayerfractions = vertical_allocation_layer_fraction[sector2verticalallocation[sector]].values
  nl = (origlayerfractions == 0).argmax()
  if nl == 0:
    nl = len(origlayerfractions)
  layerfractions = origlayerfractions[:nl]
  layerfractions /= layerfractions.sum()
  print(sector, origlayerfractions)
  print(sector, nl, layerfractions)
  print('Start.', outpath, end='')
  if os.path.exists(outpath):
    os.remove(outpath)
  emln2df = pnc.pncopen(inpath, format='netcdf')
  emln3df = emln2df.sliceDimensions(lev=[0] * nl).sliceDimensions(lev=[0] * nl)#.sliceDimensions(nhyi=[0] * (nl + 1))
  for key, var in emln3df.variables.items():
    if 'lev' in var.dimensions:
      newshape = tuple([(slice(None) if dk == 'lev' else None) for dk in var.dimensions])
      var[:] = var[:] * layerfractions[newshape]
  # hyai = emln3df.variables['hyai'][:] = [
  #   0.000000e+00, 4.804826e-02, 6.593752e+00, 1.313480e+01, 1.961311e+01, 2.609201e+01,
  #   3.257081e+01, 3.898201e+01, 4.533901e+01, 5.169611e+01, 5.805321e+01, 6.436264e+01
  # ][:nl+1]
  # hybi = emln3df.variables['hybi'][:] = [
  #   1.000000e+00, 9.849520e-01, 9.634060e-01, 9.418650e-01, 9.203870e-01, 8.989080e-01,
  #   8.774290e-01, 8.560180e-01, 8.346609e-01, 8.133039e-01, 7.919469e-01, 7.706375e-01
  # ][:nl+1]
  # emln3df.variables['hybm'][:] = np.convolve([.5, .5], hybi, mode='valid')
  # emln3df.variables['hyam'][:] = np.convolve([.5, .5], hyai, mode='valid')
  lev = emln3df.createVariable('lev', 'd', ('lev',))
  lev.long_name = "GEOS-Chem levels" ;
  lev.standard_name = "GEOS-Chem levels" ;
  lev.units = "model level" ;
  lev.positive = "up" ;
  lev[:] = np.arange(nl, dtype='i')
  # Requires special treatment in variable definition
  # to match geos-chem optimized chunking.
  outnc = emln3df.copy(variables=False).save(outpath, verbose=0)
  dimlens = {k: len(v) for k, v in emln3df.dimensions.items()}
  chunksizes = dimlens.copy()
  chunksizes['lev'] = 1
  chunksizes['time'] = 1
  for vark in emln3df.dimensions:
    if vark not in emln3df.variables:
        continue
    var = emln3df.variables[vark]
    opts = dict(complevel=0, chunksizes=tuple([dimlens[dk] for dk in var.dimensions]))
    ovar = outnc.createVariable(vark, var.dtype.char, var.dimensions, **opts)
    ovar.setncatts(var.getncatts())
    ovar[:] = var[:]
    
  for vark, var in emln3df.variables.items():
    if vark in emln3df.dimensions:
        continue
    opts = dict(complevel=1, chunksizes=tuple([chunksizes[dk] for dk in var.dimensions]))
    ovar = outnc.createVariable(vark, var.dtype.char, var.dimensions, **opts)
    ovar.setncatts(var.getncatts())
    ovar[:] = var[:]
    
  outnc.close()
  print('.Complete')
# Out:
# emln_cmv_c1c2_12 [0.53753889 0.33898293 0.12347818 0.         0.         0.
#  0.         0.         0.         0.         0.        ]
# emln_cmv_c1c2_12 3 [0.53753889 0.33898293 0.12347818]
# Start. output/2016fh_16j_emln_cmv_c1c2_12_0pt1degree_3D_month_01.ncf.Complete
# emln_cmv_c3_12 [0.53753889 0.33898293 0.12347818 0.         0.         0.
#  0.         0.         0.         0.         0.        ]
# emln_cmv_c3_12 3 [0.53753889 0.33898293 0.12347818]
# Start. output/2016fh_16j_emln_cmv_c3_12_0pt1degree_3D_month_01.ncf.Complete
# emln_ptegu [0.02792026 0.12525068 0.19615588 0.21732189 0.17116042 0.11287294
#  0.06502513 0.03777623 0.02333695 0.01420913 0.00897049]
# emln_ptegu 11 [0.02792026 0.12525068 0.19615588 0.21732189 0.17116042 0.11287294
#  0.06502513 0.03777623 0.02333695 0.01420913 0.00897049]
# Start. output/2016fh_16j_emln_ptegu_0pt1degree_3D_month_01.ncf.Complete
# emln_pt_oilgas_allinln [9.18796467e-01 5.96846291e-02 1.33246283e-02 3.97935952e-03
#  1.72454607e-03 1.03838343e-03 6.33461145e-04 3.87273438e-04
#  2.43380413e-04 1.23006844e-04 6.48650731e-05]
# emln_pt_oilgas_allinln 11 [9.18796467e-01 5.96846291e-02 1.33246283e-02 3.97935952e-03
#  1.72454607e-03 1.03838343e-03 6.33461145e-04 3.87273438e-04
#  2.43380413e-04 1.23006844e-04 6.48650731e-05]
# Start. output/2016fh_16j_emln_pt_oilgas_allinln_0pt1degree_3D_month_01.ncf.Complete
# emln_ptnonipm_allinln [7.53709868e-01 1.44705188e-01 5.29982430e-02 2.39200467e-02
#  1.10370509e-02 5.68014769e-03 3.17576317e-03 1.98002155e-03
#  1.30500180e-03 8.64739375e-04 6.23929929e-04]
# emln_ptnonipm_allinln 11 [7.53709868e-01 1.44705188e-01 5.29982430e-02 2.39200467e-02
#  1.10370509e-02 5.68014769e-03 3.17576317e-03 1.98002155e-03
#  1.30500180e-03 8.64739375e-04 6.23929929e-04]
# Start. output/2016fh_16j_emln_ptnonipm_allinln_0pt1degree_3D_month_01.ncf.Complete

# %% [markdown]
# # Now Do a Mass Conservation Check
#
# * Open the 3d file
# * Open the reference file
# * Sum the values and compare

# %%
from glob import glob

emln3dpaths = sorted(glob('output/*_3D_*.ncf'))
for inpath in emln3dpaths:
    refpath = inpath.replace('_3D', '')
    f3d = pnc.pncopen(inpath)
    fref = pnc.pncopen(refpath)
    print(refpath)
    print('emln   {:2d} lev NOX {:.7e} sum kgNO2/m2/s'.format(len(fref.dimensions['lev']), fref.variables['NOX'][:].sum()))
    print('emln3d {:2d} lev NOX {:.7e} sum kgNO2/m2/s'.format(len(f3d.dimensions['lev']), f3d.variables['NOX'][:].sum()))
    print('Within numerical precision', np.allclose(fref.variables['NOX'][:, 0], f3d.variables['NOX'][:].sum(1)))
    fref.close()
    f3d.close()
# Out:
# output/2016fh_16j_emln_cmv_c1c2_12_0pt1degree_month_01.ncf
# emln    1 lev NOX 4.7259743e-08 sum kgNO2/m2/s
# emln3d  3 lev NOX 4.7259750e-08 sum kgNO2/m2/s
# Within numerical precision True
# output/2016fh_16j_emln_cmv_c3_12_0pt1degree_month_01.ncf
# emln    1 lev NOX 1.7865638e-07 sum kgNO2/m2/s
# emln3d  3 lev NOX 1.7865639e-07 sum kgNO2/m2/s
# Within numerical precision True
# **PNC:/home/emfreese/anaconda3/envs/conda_env/lib/python3.7/site-packages/PseudoNetCDF/pncwarn.py:24:UserWarning:
#   NetCDF: Not a valid ID
# output/2016fh_16j_emln_pt_oilgas_allinln_0pt1degree_month_01.ncf
# emln    1 lev NOX 1.1136418e-07 sum kgNO2/m2/s
# emln3d 11 lev NOX 1.1136420e-07 sum kgNO2/m2/s
# Within numerical precision True
# output/2016fh_16j_emln_ptegu_0pt1degree_month_01.ncf
# emln    1 lev NOX 4.2782983e-07 sum kgNO2/m2/s
# emln3d 11 lev NOX 4.2782992e-07 sum kgNO2/m2/s
# Within numerical precision True
# output/2016fh_16j_emln_ptnonipm_allinln_0pt1degree_month_01.ncf
# emln    1 lev NOX 2.7841543e-07 sum kgNO2/m2/s
# emln3d 11 lev NOX 2.7841529e-07 sum kgNO2/m2/s
# Within numerical precision True

# %% [markdown]
# # Configure Translation from CMAQ to GEOS-Chem
#
# * Translation is not always 1:1
# * Apply scaling factors
#   * Diurnal scale factors (25, 26)
#   * Day of week (210-222)
#   * Split OC/EC (70-73)
#   * Convert NO kgNO2/m2/s to kgNO/m2/s (115)

# %%
cq2gc = {
    'ACET': [['ACET', '26/213/1007']],
    'ALD2': [['ALD2', '26/213/1007']],
    'ALDX': [['RCHO', '26/213/1007']],
    'ACROLEIN': [['MACR', '26/213/1007']],
    'BENZ': [['BENZ', '26/213/1007']],
    'ECH4': [['CH4', '1007']],
    'CL': [['Cl', '1007']],
    'CL2': [['Cl2', '1007']],
    'CLO': [['ClO', '1007']],
    'CLNO2': [['ClNO2', '1007']],
    'CLNO3': [['ClNO3', '1007']],
    'CO': [['CO', '26/211/1007']],
    'ETOH': [['EOH', '26/213/1007']],
    'ETHA': [['C2H6', '26/217/1007']],
    'ETH': [['C2H4', '26/213/1007']],
    'FACD': [['HCOOH', '26/213/1007']],
    'FORM': [['CH2O', '26/213/1007']],
    'GLY': [['GLYX', '26/214/1007']], # Following MEK
    'GLYD': [['GLYC', '26/214/1007']], # Following MEK
    'HCL': [['HCl', '1007']],
    'HOCL': [['HOCl', '1007']],
    'HONO': [['HNO2', '25/210/1007']],
    'HPLD': [['HPALD', '26/214/1007']], # Following MEK
    'IOLE': [['PRPE', '26/215/1007']],
    'KET': [['MEK', '26/214/1007']],
    'MEPX': [['MP', '26/213/1007']], # Following MEOH
    'MEOH': [['MOH', '26/213/1007']],
    'NH3': [['NH3', '26/213/1007']],
    'NO': [['NO', '115/25/210/1007']],
    'NO2': [['NO2', '25/210/1007']],
    'OLE': [['PRPE', '26/215/1007']],
    'PACD': [['MAP', '26/213/1007']], # Following MEOH
    'PAR': [['ALK4', '26/212/1007']],
    'PNA': [['HNO4', '26/213/1007']], # Following MEOH
    'PRPA': [['C3H8', '26/216/1007']],
    'SO2': [['SO2', '26/218/1007']],
    'SULF': [['SO4', '26/218/1007']],
    'TOL': [['TOLU', '26/213/1007']],
    'PEC': [['BCPI', '26/221/1007/70'], ['BCPO', '26/221/256/1007/71']],
    'PFE': [['pFe', '26/219/1007']],
    'POC': [['OCPI', '26/222/1007/72'], ['OCPO', '26/222/257/1007/73']],
    'PNH4': [['NH4', '26/218/1007']], # need to confirm this
    'PNO3': [['NIT', '26/218/1007']], # need to confirm this
    'PSO4': [['SO4', '26/219/1007']],
    'XYLMN': [['XYLE', '26/213/1007']],
}
# Ignore special species
exec('ALD2_PRIMARY = FORM_PRIMARY = NH3_FERT = []', None, cq2gc)
# ignore inventory meta variables
exec('HFLUX = VOC_INV = VOC_BEIS = CO2_INV = N2O_INV = CH4_INV = []', None, cq2gc)
# Ignore duplicative species
# TOLU in TOL
# NOX = NO + NO2 + HONO
# CH4 in ECH4
exec('CH4 = TOLU = NOX = []', None, cq2gc)
# Ignore coordinate variables
exec('hybm = hyam = []', None, cq2gc)
# Ignore APIN, BPIN, and SESQ - they were from BEIS
# and were removed
exec('APIN = BPIN = SESQ = []', None, cq2gc)
# ISOP and TERP are mostly biogenic, so igoring remainder
exec('ISOP = TERP = []', None, cq2gc)
# Ignore species GC doesn't have
exec('BUTADIENE13 = ETHY = NAPH = []', None, cq2gc)
# unreactive and nonvolatile are not used
exec('UNK = UNR = NVOL = NR = []', None, cq2gc)
# Ignore unused particulate species
exec('SOAALK = PAL = PCA = PCL = PFE = PH2O = PK = PSI = PTI = []', None, cq2gc)
exec('PM2_5 = PMC = PMG = PMN = PMOTHR = PNCOM = P = PCA = PCL = PFE = PH2O = PK = []', None, cq2gc)

# %% [markdown]
# # Define HEMCO_Config.rc Writer
#
# * Create a HEMCO_Config.rc that reads all included files
# * Only needed to be made once and editted to use $MM instead of 01..12

# %%
def changepathtopattern(path):
  return '$ROOT/NEI2016fh/' + path.replace('month_' + month, 'month_$MM')

def getsector(hcpath):
    sector = hcpath.split('16j_')[1].split('_0pt')[0]
    sector = sector.replace('emln_', '').replace('_allinln', '').replace('_12', '').replace('_adj', '').replace('cmv_', '')
    sector = sector.replace('_oilgas', 'og')
    return sector

def writeconfig(sectors, outpath):
    hcpaths = []
    for sector in sectors:
      hemco2dpath = hemcotmpl(sector=sector, month=month)
      hemco3dpath = hemco2dpath.replace('0pt1degree', '0pt1degree_3D')
      if os.path.exists(hemco3dpath):
          hcpaths.append(hemco3dpath)
      elif os.path.exists(hemco2dpath):
          hcpaths.append(hemco2dpath)
      else:
          raise KeyError('Could not find regridded: ' + hemco2dpath)

    defaults = set()
    ignores = set()
    with open(outpath, 'w') as hcf:
        hcf.write('(((EPA2016_MONMEAN\n')
        for hcpath in hcpaths:
            hcpatt = changepathtopattern(hcpath)
            sector = getsector(hcpath)
            print(sector, hcpatt, end='', flush=True)
            hcfile = pnc.pncopen(hcpath, format='netcdf')
            for cqkey, v in hcfile.variables.items():
                if cqkey in hcfile.dimensions or cqkey in ('hyai', 'hybi'):
                  continue
                elif cqkey in ('TOLU',):
                  warn('TOLU mass is duplicated by TOL')
                if cqkey in cq2gc:
                  gctrans = cq2gc.get(cqkey)
                  if len(gctrans) == 0:
                    ignores.add(cqkey)
                else:
                  defaults.add(cqkey)
                  gctrans = [[cqkey, '1007']]
                for gckey, scale in gctrans:
                  if gckey in ['ACET', 'MEK', 'ALD2', 'PRPE', 'PRPA', 'BENZ', 'TOLU', 'XYLE', 'EOH', 'ALK4', 'ISOP']:
                    units = 'kgC/m2/s'
                  else:
                    units = v.units.strip()
                  opts = dict(
                    unit=units,
                    gckey=gckey,
                    cqkey=cqkey,
                    sector=sector,
                    path=hcpatt,
                    scale=scale,
                    cat='1/2',
                    hier=50
                  )
                  hcf.write('0 EPA16_{gckey}__{sector}{cqkey} {path}  {cqkey}       2016-2016/1-12/1/0 C xyz  {unit}  {gckey}   {scale}     {cat} {hier}\n'.format(**opts))
                  # If I use - to repeat the file, the mass is from the previous cqkey too.
                  # hcpatt = '-'
            print()
        hcf.write(')))EPA2016_MONMEAN\n')
    print('Ignored', sorted(ignores))
    print('Defaults', sorted(defaults))

# %% [markdown]
# # Choose paths to use in HEMCO
#
# * hemco3d files take precedence
# * hemco2d are the default
# * Must have one or the other

# %%
writeconfig(include_sectors, 'output/EPA_Config.rc')
writeconfig(['merge_areaonly', 'merge_intl'] + ptonly_sectors + allinln_sectors, 'output/EPAMERGED_Config.rc')
# Out:
# afdust $ROOT/NEI2016fh/output/2016fh_16j_afdust_adj_0pt1degree_month_$MM.ncf
# ag $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf
# airports $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf
# nonpt $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf
# nonroad $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf
# npog $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf
# onroad $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf
# onroad_ca $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf
# rail $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf
# rwc $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf
# c1c2 $ROOT/NEI2016fh/output/2016fh_16j_emln_cmv_c1c2_12_0pt1degree_3D_month_$MM.ncf
# c3 $ROOT/NEI2016fh/output/2016fh_16j_emln_cmv_c3_12_0pt1degree_3D_month_$MM.ncf
# ptegu $ROOT/NEI2016fh/output/2016fh_16j_emln_ptegu_0pt1degree_3D_month_$MM.ncf
# ptog $ROOT/NEI2016fh/output/2016fh_16j_emln_pt_oilgas_allinln_0pt1degree_3D_month_$MM.ncf
# ptnonipm $ROOT/NEI2016fh/output/2016fh_16j_emln_ptnonipm_allinln_0pt1degree_3D_month_$MM.ncf
# onroad_can $ROOT/NEI2016fh/output/2016fh_16j_onroad_can_0pt1degree_month_$MM.ncf
# onroad_mex $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf
# othafdust $ROOT/NEI2016fh/output/2016fh_16j_othafdust_adj_0pt1degree_month_$MM.ncf
# othar $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf
# othptdust $ROOT/NEI2016fh/output/2016fh_16j_othptdust_adj_0pt1degree_month_$MM.ncf
# othpt $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf
# Ignored ['ALD2_PRIMARY', 'BUTADIENE13', 'CH4', 'CH4_INV', 'CO2_INV', 'ETHY', 'FORM_PRIMARY', 'ISOP', 'N2O_INV', 'NAPH', 'NH3_FERT', 'NOX', 'NVOL', 'PAL', 'PCA', 'PCL', 'PFE', 'PH2O', 'PK', 'PM2_5', 'PMC', 'PMG', 'PMN', 'PMOTHR', 'PNCOM', 'PSI', 'PTI', 'SOAALK', 'TERP', 'UNK', 'UNR', 'VOC_INV']
# Defaults []
# merge_areaonly $ROOT/NEI2016fh/output/2016fh_16j_merge_areaonly_0pt1degree_month_$MM.ncf
# merge_intl $ROOT/NEI2016fh/output/2016fh_16j_merge_intl_0pt1degree_month_$MM.ncf
# c1c2 $ROOT/NEI2016fh/output/2016fh_16j_emln_cmv_c1c2_12_0pt1degree_3D_month_$MM.ncf
# c3 $ROOT/NEI2016fh/output/2016fh_16j_emln_cmv_c3_12_0pt1degree_3D_month_$MM.ncf
# ptegu $ROOT/NEI2016fh/output/2016fh_16j_emln_ptegu_0pt1degree_3D_month_$MM.ncf
# ptog $ROOT/NEI2016fh/output/2016fh_16j_emln_pt_oilgas_allinln_0pt1degree_3D_month_$MM.ncf
# ptnonipm $ROOT/NEI2016fh/output/2016fh_16j_emln_ptnonipm_allinln_0pt1degree_3D_month_$MM.ncf
# Ignored ['ALD2_PRIMARY', 'BUTADIENE13', 'CH4', 'CH4_INV', 'CO2_INV', 'ETHY', 'FORM_PRIMARY', 'ISOP', 'N2O_INV', 'NAPH', 'NH3_FERT', 'NOX', 'NVOL', 'PAL', 'PCA', 'PCL', 'PFE', 'PH2O', 'PK', 'PM2_5', 'PMC', 'PMG', 'PMN', 'PMOTHR', 'PNCOM', 'PSI', 'PTI', 'SOAALK', 'TERP', 'UNK', 'UNR', 'VOC_INV']
# Defaults []

# %% [markdown]
# # Review the HEMCO file

# %%
less output/EPA_Config.rc
# Out:
# /home/emfreese/anaconda3/envs/conda_env/lib/python3.7/site-packages/ipykernel/zmqshell.py:342: ResourceWarning: unclosed file <_io.TextIOWrapper name='output/EPA_Config.rc' mode='r' encoding='UTF-8'>
#   cont = open(arg_s).read()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# (((EPA2016_MONMEAN
# 0 EPA16_BCPI__afdustPEC $ROOT/NEI2016fh/output/2016fh_16j_afdust_adj_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__afdustPEC $ROOT/NEI2016fh/output/2016fh_16j_afdust_adj_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__afdustPNA $ROOT/NEI2016fh/output/2016fh_16j_afdust_adj_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__afdustPNH4 $ROOT/NEI2016fh/output/2016fh_16j_afdust_adj_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__afdustPNO3 $ROOT/NEI2016fh/output/2016fh_16j_afdust_adj_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__afdustPOC $ROOT/NEI2016fh/output/2016fh_16j_afdust_adj_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__afdustPOC $ROOT/NEI2016fh/output/2016fh_16j_afdust_adj_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_SO4__afdustPSO4 $ROOT/NEI2016fh/output/2016fh_16j_afdust_adj_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_ACET__agACET $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_ALD2__agALD2 $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__agALDX $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__agBENZ $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_C2H4__agETH $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__agETHA $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__agETOH $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__agFORM $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_PRPE__agIOLE $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__agKET $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__agMEOH $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NH3__agNH3 $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  NH3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH3   26/213/1007     1/2 50
# 0 EPA16_PRPE__agOLE $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__agPAR $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_C3H8__agPRPA $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_TOLU__agTOL $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__agXYLMN $ROOT/NEI2016fh/output/2016fh_16j_ag_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_ACET__airportsACET $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_MACR__airportsACROLEIN $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  ACROLEIN       2016-2016/1-12/1/0 C xyz  kg/m2/s  MACR   26/213/1007     1/2 50
# 0 EPA16_ALD2__airportsALD2 $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__airportsALDX $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__airportsBENZ $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_CO__airportsCO $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  CO       2016-2016/1-12/1/0 C xyz  kg/m2/s  CO   26/211/1007     1/2 50
# 0 EPA16_C2H4__airportsETH $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__airportsETHA $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__airportsETOH $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__airportsFORM $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_HNO2__airportsHONO $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  HONO       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__airportsIOLE $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__airportsKET $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__airportsMEOH $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NO__airportsNO $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  NO       2016-2016/1-12/1/0 C xyz  kgNO2/m2/s  NO   115/25/210/1007     1/2 50
# 0 EPA16_NO2__airportsNO2 $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  NO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  NO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__airportsOLE $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__airportsPAR $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__airportsPEC $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__airportsPEC $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__airportsPNA $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__airportsPNH4 $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__airportsPNO3 $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__airportsPOC $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__airportsPOC $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__airportsPRPA $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__airportsPSO4 $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__airportsSO2 $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_SO4__airportsSULF $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  SULF       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/218/1007     1/2 50
# 0 EPA16_TOLU__airportsTOL $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__airportsXYLMN $ROOT/NEI2016fh/output/2016fh_16j_airports_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_ACET__nonptACET $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_MACR__nonptACROLEIN $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  ACROLEIN       2016-2016/1-12/1/0 C xyz  kg/m2/s  MACR   26/213/1007     1/2 50
# 0 EPA16_ALD2__nonptALD2 $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__nonptALDX $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__nonptBENZ $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_Cl2__nonptCL2 $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  CL2       2016-2016/1-12/1/0 C xyz  kg/m2/s  Cl2   1007     1/2 50
# 0 EPA16_CO__nonptCO $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  CO       2016-2016/1-12/1/0 C xyz  kg/m2/s  CO   26/211/1007     1/2 50
# 0 EPA16_C2H4__nonptETH $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__nonptETHA $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__nonptETOH $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__nonptFORM $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_HCl__nonptHCL $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  HCL       2016-2016/1-12/1/0 C xyz  kg/m2/s  HCl   1007     1/2 50
# 0 EPA16_HNO2__nonptHONO $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  HONO       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__nonptIOLE $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__nonptKET $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__nonptMEOH $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NH3__nonptNH3 $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  NH3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH3   26/213/1007     1/2 50
# 0 EPA16_NO__nonptNO $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  NO       2016-2016/1-12/1/0 C xyz  kgNO2/m2/s  NO   115/25/210/1007     1/2 50
# 0 EPA16_NO2__nonptNO2 $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  NO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  NO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__nonptOLE $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__nonptPAR $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__nonptPEC $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__nonptPEC $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__nonptPNA $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__nonptPNH4 $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__nonptPNO3 $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__nonptPOC $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__nonptPOC $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__nonptPRPA $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__nonptPSO4 $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__nonptSO2 $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_SO4__nonptSULF $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  SULF       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/218/1007     1/2 50
# 0 EPA16_TOLU__nonptTOL $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__nonptXYLMN $ROOT/NEI2016fh/output/2016fh_16j_nonpt_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_ACET__nonroadACET $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_MACR__nonroadACROLEIN $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  ACROLEIN       2016-2016/1-12/1/0 C xyz  kg/m2/s  MACR   26/213/1007     1/2 50
# 0 EPA16_ALD2__nonroadALD2 $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__nonroadALDX $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__nonroadBENZ $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_CO__nonroadCO $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  CO       2016-2016/1-12/1/0 C xyz  kg/m2/s  CO   26/211/1007     1/2 50
# 0 EPA16_C2H4__nonroadETH $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__nonroadETHA $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__nonroadETOH $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__nonroadFORM $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_HNO2__nonroadHONO $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  HONO       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__nonroadIOLE $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__nonroadKET $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__nonroadMEOH $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NH3__nonroadNH3 $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  NH3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH3   26/213/1007     1/2 50
# 0 EPA16_NO__nonroadNO $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  NO       2016-2016/1-12/1/0 C xyz  kgNO2/m2/s  NO   115/25/210/1007     1/2 50
# 0 EPA16_NO2__nonroadNO2 $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  NO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  NO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__nonroadOLE $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__nonroadPAR $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__nonroadPEC $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__nonroadPEC $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__nonroadPNA $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__nonroadPNH4 $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__nonroadPNO3 $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__nonroadPOC $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__nonroadPOC $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__nonroadPRPA $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__nonroadPSO4 $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__nonroadSO2 $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_SO4__nonroadSULF $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  SULF       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/218/1007     1/2 50
# 0 EPA16_TOLU__nonroadTOL $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__nonroadXYLMN $ROOT/NEI2016fh/output/2016fh_16j_nonroad_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_ACET__npogACET $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_MACR__npogACROLEIN $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  ACROLEIN       2016-2016/1-12/1/0 C xyz  kg/m2/s  MACR   26/213/1007     1/2 50
# 0 EPA16_ALD2__npogALD2 $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__npogALDX $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__npogBENZ $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_Cl2__npogCL2 $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  CL2       2016-2016/1-12/1/0 C xyz  kg/m2/s  Cl2   1007     1/2 50
# 0 EPA16_CO__npogCO $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  CO       2016-2016/1-12/1/0 C xyz  kg/m2/s  CO   26/211/1007     1/2 50
# 0 EPA16_C2H4__npogETH $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__npogETHA $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__npogETOH $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__npogFORM $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_HNO2__npogHONO $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  HONO       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__npogIOLE $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__npogKET $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__npogMEOH $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NH3__npogNH3 $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  NH3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH3   26/213/1007     1/2 50
# 0 EPA16_NO__npogNO $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  NO       2016-2016/1-12/1/0 C xyz  kgNO2/m2/s  NO   115/25/210/1007     1/2 50
# 0 EPA16_NO2__npogNO2 $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  NO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  NO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__npogOLE $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__npogPAR $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__npogPEC $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__npogPEC $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__npogPNA $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__npogPNH4 $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__npogPNO3 $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__npogPOC $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__npogPOC $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__npogPRPA $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__npogPSO4 $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__npogSO2 $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_SO4__npogSULF $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  SULF       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/218/1007     1/2 50
# 0 EPA16_TOLU__npogTOL $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__npogXYLMN $ROOT/NEI2016fh/output/2016fh_16j_np_oilgas_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_ACET__onroadACET $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_MACR__onroadACROLEIN $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  ACROLEIN       2016-2016/1-12/1/0 C xyz  kg/m2/s  MACR   26/213/1007     1/2 50
# 0 EPA16_ALD2__onroadALD2 $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__onroadALDX $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__onroadBENZ $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_CO__onroadCO $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  CO       2016-2016/1-12/1/0 C xyz  kg/m2/s  CO   26/211/1007     1/2 50
# 0 EPA16_C2H4__onroadETH $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__onroadETHA $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__onroadETOH $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__onroadFORM $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_HNO2__onroadHONO $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  HONO       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__onroadIOLE $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__onroadKET $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__onroadMEOH $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NH3__onroadNH3 $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  NH3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH3   26/213/1007     1/2 50
# 0 EPA16_NO__onroadNO $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  NO       2016-2016/1-12/1/0 C xyz  kgNO2/m2/s  NO   115/25/210/1007     1/2 50
# 0 EPA16_NO2__onroadNO2 $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  NO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  NO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__onroadOLE $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__onroadPAR $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__onroadPEC $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__onroadPEC $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__onroadPNA $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__onroadPNH4 $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__onroadPNO3 $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__onroadPOC $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__onroadPOC $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__onroadPRPA $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__onroadPSO4 $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__onroadSO2 $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_TOLU__onroadTOL $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__onroadXYLMN $ROOT/NEI2016fh/output/2016fh_16j_onroad_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_ACET__onroad_caACET $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_MACR__onroad_caACROLEIN $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  ACROLEIN       2016-2016/1-12/1/0 C xyz  kg/m2/s  MACR   26/213/1007     1/2 50
# 0 EPA16_ALD2__onroad_caALD2 $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__onroad_caALDX $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__onroad_caBENZ $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_CO__onroad_caCO $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  CO       2016-2016/1-12/1/0 C xyz  kg/m2/s  CO   26/211/1007     1/2 50
# 0 EPA16_C2H4__onroad_caETH $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__onroad_caETHA $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__onroad_caETOH $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__onroad_caFORM $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_HNO2__onroad_caHONO $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  HONO       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__onroad_caIOLE $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__onroad_caKET $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__onroad_caMEOH $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NH3__onroad_caNH3 $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  NH3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH3   26/213/1007     1/2 50
# 0 EPA16_NO__onroad_caNO $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  NO       2016-2016/1-12/1/0 C xyz  kgNO2/m2/s  NO   115/25/210/1007     1/2 50
# 0 EPA16_NO2__onroad_caNO2 $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  NO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  NO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__onroad_caOLE $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__onroad_caPAR $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__onroad_caPEC $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__onroad_caPEC $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__onroad_caPNA $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__onroad_caPNH4 $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__onroad_caPNO3 $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__onroad_caPOC $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__onroad_caPOC $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__onroad_caPRPA $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__onroad_caPSO4 $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__onroad_caSO2 $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_TOLU__onroad_caTOL $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__onroad_caXYLMN $ROOT/NEI2016fh/output/2016fh_16j_onroad_ca_adj_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_ACET__railACET $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_MACR__railACROLEIN $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  ACROLEIN       2016-2016/1-12/1/0 C xyz  kg/m2/s  MACR   26/213/1007     1/2 50
# 0 EPA16_ALD2__railALD2 $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__railALDX $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__railBENZ $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_CO__railCO $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  CO       2016-2016/1-12/1/0 C xyz  kg/m2/s  CO   26/211/1007     1/2 50
# 0 EPA16_C2H4__railETH $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__railETHA $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__railETOH $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__railFORM $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_HNO2__railHONO $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  HONO       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__railIOLE $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__railKET $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__railMEOH $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NH3__railNH3 $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  NH3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH3   26/213/1007     1/2 50
# 0 EPA16_NO__railNO $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  NO       2016-2016/1-12/1/0 C xyz  kgNO2/m2/s  NO   115/25/210/1007     1/2 50
# 0 EPA16_NO2__railNO2 $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  NO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  NO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__railOLE $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__railPAR $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__railPEC $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__railPEC $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__railPNA $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__railPNH4 $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__railPNO3 $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__railPOC $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__railPOC $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__railPRPA $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__railPSO4 $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__railSO2 $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_SO4__railSULF $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  SULF       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/218/1007     1/2 50
# 0 EPA16_TOLU__railTOL $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__railXYLMN $ROOT/NEI2016fh/output/2016fh_16j_rail_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_ACET__rwcACET $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_MACR__rwcACROLEIN $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  ACROLEIN       2016-2016/1-12/1/0 C xyz  kg/m2/s  MACR   26/213/1007     1/2 50
# 0 EPA16_ALD2__rwcALD2 $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__rwcALDX $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__rwcBENZ $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_Cl2__rwcCL2 $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  CL2       2016-2016/1-12/1/0 C xyz  kg/m2/s  Cl2   1007     1/2 50
# 0 EPA16_CO__rwcCO $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  CO       2016-2016/1-12/1/0 C xyz  kg/m2/s  CO   26/211/1007     1/2 50
# 0 EPA16_C2H4__rwcETH $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__rwcETHA $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__rwcETOH $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__rwcFORM $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_HNO2__rwcHONO $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  HONO       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__rwcIOLE $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__rwcKET $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__rwcMEOH $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NH3__rwcNH3 $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  NH3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH3   26/213/1007     1/2 50
# 0 EPA16_NO__rwcNO $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  NO       2016-2016/1-12/1/0 C xyz  kgNO2/m2/s  NO   115/25/210/1007     1/2 50
# 0 EPA16_NO2__rwcNO2 $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  NO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  NO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__rwcOLE $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__rwcPAR $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__rwcPEC $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__rwcPEC $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__rwcPNA $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__rwcPNH4 $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__rwcPNO3 $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__rwcPOC $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__rwcPOC $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__rwcPRPA $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__rwcPSO4 $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__rwcSO2 $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_SO4__rwcSULF $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  SULF       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/218/1007     1/2 50
# 0 EPA16_TOLU__rwcTOL $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__rwcXYLMN $ROOT/NEI2016fh/output/2016fh_16j_rwc_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_ACET__c1c2ACET $ROOT/NEI2016fh/output/2016fh_16j_emln_cmv_c1c2_12_0pt1degree_3D_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_ALD2__c1c2ALD2 $ROOT/NEI2016fh/output/2016fh_16j_emln_cmv_c1c2_12_0pt1degree_3D_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# ...
# 0 EPA16_PRPE__onroad_mexOLE $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__onroad_mexPAR $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__onroad_mexPEC $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__onroad_mexPEC $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__onroad_mexPNA $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__onroad_mexPNH4 $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__onroad_mexPNO3 $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__onroad_mexPOC $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__onroad_mexPOC $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__onroad_mexPRPA $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__onroad_mexPSO4 $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__onroad_mexSO2 $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_SO4__onroad_mexSULF $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  SULF       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/218/1007     1/2 50
# 0 EPA16_TOLU__onroad_mexTOL $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__onroad_mexXYLMN $ROOT/NEI2016fh/output/2016fh_16j_onroad_mex_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_BCPI__othafdustPEC $ROOT/NEI2016fh/output/2016fh_16j_othafdust_adj_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__othafdustPEC $ROOT/NEI2016fh/output/2016fh_16j_othafdust_adj_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__othafdustPNA $ROOT/NEI2016fh/output/2016fh_16j_othafdust_adj_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__othafdustPNH4 $ROOT/NEI2016fh/output/2016fh_16j_othafdust_adj_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__othafdustPNO3 $ROOT/NEI2016fh/output/2016fh_16j_othafdust_adj_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__othafdustPOC $ROOT/NEI2016fh/output/2016fh_16j_othafdust_adj_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__othafdustPOC $ROOT/NEI2016fh/output/2016fh_16j_othafdust_adj_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_SO4__othafdustPSO4 $ROOT/NEI2016fh/output/2016fh_16j_othafdust_adj_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_ACET__otharACET $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_ALD2__otharALD2 $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__otharALDX $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__otharBENZ $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_CO__otharCO $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  CO       2016-2016/1-12/1/0 C xyz  kg/m2/s  CO   26/211/1007     1/2 50
# 0 EPA16_C2H4__otharETH $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__otharETHA $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__otharETOH $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__otharFORM $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_HNO2__otharHONO $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  HONO       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__otharIOLE $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__otharKET $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__otharMEOH $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NH3__otharNH3 $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  NH3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH3   26/213/1007     1/2 50
# 0 EPA16_NO__otharNO $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  NO       2016-2016/1-12/1/0 C xyz  kgNO2/m2/s  NO   115/25/210/1007     1/2 50
# 0 EPA16_NO2__otharNO2 $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  NO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  NO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__otharOLE $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__otharPAR $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__otharPEC $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__otharPEC $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__otharPNA $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__otharPNH4 $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__otharPNO3 $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__otharPOC $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__otharPOC $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__otharPRPA $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__otharPSO4 $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__otharSO2 $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_SO4__otharSULF $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  SULF       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/218/1007     1/2 50
# 0 EPA16_TOLU__otharTOL $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__otharXYLMN $ROOT/NEI2016fh/output/2016fh_16j_othar_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# 0 EPA16_BCPI__othptdustPEC $ROOT/NEI2016fh/output/2016fh_16j_othptdust_adj_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__othptdustPEC $ROOT/NEI2016fh/output/2016fh_16j_othptdust_adj_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__othptdustPNA $ROOT/NEI2016fh/output/2016fh_16j_othptdust_adj_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__othptdustPNH4 $ROOT/NEI2016fh/output/2016fh_16j_othptdust_adj_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__othptdustPNO3 $ROOT/NEI2016fh/output/2016fh_16j_othptdust_adj_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__othptdustPOC $ROOT/NEI2016fh/output/2016fh_16j_othptdust_adj_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__othptdustPOC $ROOT/NEI2016fh/output/2016fh_16j_othptdust_adj_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_SO4__othptdustPSO4 $ROOT/NEI2016fh/output/2016fh_16j_othptdust_adj_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_ACET__othptACET $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  ACET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ACET   26/213/1007     1/2 50
# 0 EPA16_ALD2__othptALD2 $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  ALD2       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALD2   26/213/1007     1/2 50
# 0 EPA16_RCHO__othptALDX $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  ALDX       2016-2016/1-12/1/0 C xyz  kg/m2/s  RCHO   26/213/1007     1/2 50
# 0 EPA16_BENZ__othptBENZ $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  BENZ       2016-2016/1-12/1/0 C xyz  kgC/m2/s  BENZ   26/213/1007     1/2 50
# 0 EPA16_CO__othptCO $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  CO       2016-2016/1-12/1/0 C xyz  kg/m2/s  CO   26/211/1007     1/2 50
# 0 EPA16_C2H4__othptETH $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  ETH       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H4   26/213/1007     1/2 50
# 0 EPA16_C2H6__othptETHA $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  ETHA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C2H6   26/217/1007     1/2 50
# 0 EPA16_EOH__othptETOH $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  ETOH       2016-2016/1-12/1/0 C xyz  kgC/m2/s  EOH   26/213/1007     1/2 50
# 0 EPA16_CH2O__othptFORM $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  FORM       2016-2016/1-12/1/0 C xyz  kg/m2/s  CH2O   26/213/1007     1/2 50
# 0 EPA16_HNO2__othptHONO $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  HONO       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__othptIOLE $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  IOLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_MEK__othptKET $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  KET       2016-2016/1-12/1/0 C xyz  kgC/m2/s  MEK   26/214/1007     1/2 50
# 0 EPA16_MOH__othptMEOH $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  MEOH       2016-2016/1-12/1/0 C xyz  kg/m2/s  MOH   26/213/1007     1/2 50
# 0 EPA16_NH3__othptNH3 $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  NH3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH3   26/213/1007     1/2 50
# 0 EPA16_NO__othptNO $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  NO       2016-2016/1-12/1/0 C xyz  kgNO2/m2/s  NO   115/25/210/1007     1/2 50
# 0 EPA16_NO2__othptNO2 $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  NO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  NO2   25/210/1007     1/2 50
# 0 EPA16_PRPE__othptOLE $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  OLE       2016-2016/1-12/1/0 C xyz  kgC/m2/s  PRPE   26/215/1007     1/2 50
# 0 EPA16_ALK4__othptPAR $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  PAR       2016-2016/1-12/1/0 C xyz  kgC/m2/s  ALK4   26/212/1007     1/2 50
# 0 EPA16_BCPI__othptPEC $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPI   26/221/1007/70     1/2 50
# 0 EPA16_BCPO__othptPEC $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  PEC       2016-2016/1-12/1/0 C xyz  kg/m2/s  BCPO   26/221/256/1007/71     1/2 50
# 0 EPA16_HNO4__othptPNA $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  PNA       2016-2016/1-12/1/0 C xyz  kg/m2/s  HNO4   26/213/1007     1/2 50
# 0 EPA16_NH4__othptPNH4 $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  PNH4       2016-2016/1-12/1/0 C xyz  kg/m2/s  NH4   26/218/1007     1/2 50
# 0 EPA16_NIT__othptPNO3 $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  PNO3       2016-2016/1-12/1/0 C xyz  kg/m2/s  NIT   26/218/1007     1/2 50
# 0 EPA16_OCPI__othptPOC $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPI   26/222/1007/72     1/2 50
# 0 EPA16_OCPO__othptPOC $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  POC       2016-2016/1-12/1/0 C xyz  kg/m2/s  OCPO   26/222/257/1007/73     1/2 50
# 0 EPA16_C3H8__othptPRPA $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  PRPA       2016-2016/1-12/1/0 C xyz  kg/m2/s  C3H8   26/216/1007     1/2 50
# 0 EPA16_SO4__othptPSO4 $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  PSO4       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/219/1007     1/2 50
# 0 EPA16_SO2__othptSO2 $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  SO2       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO2   26/218/1007     1/2 50
# 0 EPA16_SO4__othptSULF $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  SULF       2016-2016/1-12/1/0 C xyz  kg/m2/s  SO4   26/218/1007     1/2 50
# 0 EPA16_TOLU__othptTOL $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  TOL       2016-2016/1-12/1/0 C xyz  kgC/m2/s  TOLU   26/213/1007     1/2 50
# 0 EPA16_XYLE__othptXYLMN $ROOT/NEI2016fh/output/2016fh_16j_emln_othpt_0pt1degree_month_$MM.ncf  XYLMN       2016-2016/1-12/1/0 C xyz  kgC/m2/s  XYLE   26/213/1007     1/2 50
# )))EPA2016_MONMEAN

# %% [markdown]
# # Summary
#
# You've created 3 important in the output folder.
# 1. A 3D emln file with no fires.
# 2. A 2D gridded file with no beis
# 3. A HEMCO_Config.rc file
#
# The are two additional files that are just references:
# 1. tot_nobeis_nofire is a refernce fo the expected total
# 2. emln_nofire (non-3D)
#
# Download the output directory

# %%
os.system('zip output.zip output/*')
# Out:
# 0

# %%
ls -lh output.zip
# Out:
# -rw-r--r-- 1 root root 425M Jun 25 15:11 output.zip
